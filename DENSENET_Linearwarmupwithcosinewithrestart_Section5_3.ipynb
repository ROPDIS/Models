# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_Linearwarmupwithcosinewithrestart_Section5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
# !pip install tensorflow==2.13
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC
# Out:
# Requirement already satisfied: tensorflow==2.13 in /usr/local/lib/python3.10/dist-packages (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.13) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow==2.13) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13) (3.2.2)

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.Flatten())
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  flatten (Flatten)           (None, 3840)              0
#
#  batch_normalization (Batch  (None, 3840)              15360
#  Normalization)
#
#  dropout (Dropout)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20306497 (77.46 MB)
# Trainable params: 1975809 (7.54 MB)
# Non-trainable params: 18330688 (69.93 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PolynomialDecay, CosineDecay
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping

first_decay_steps=3000
initial_learning_rate = 0.02

lr_warmup_decayed_fn = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate, first_decay_steps, t_mul=1.2, m_mul=0.2, alpha=0.00000002
)

# Configure the LearningRateScheduler callback
learning_rate_scheduler = LearningRateScheduler(lr_warmup_decayed_fn)


dense.compile(optimizer=Adam(learning_rate=lr_warmup_decayed_fn), loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),learning_rate_scheduler])

# Print the learning rate history
print(history.history["lr"])
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3334s 6s/step - loss: 53.5612 - precision: 0.6461 - recall: 0.7711 - auc: 0.6971 - accuracy: 0.6481 - f_score: 0.6975 - val_loss: 46.0699 - val_precision: 0.9332 - val_recall: 0.9332 - val_auc: 0.6150 - val_accuracy: 0.8783 - val_f_score: 0.9309 - lr: 0.0183
# Epoch 2/45
# 562/562 [==============================] - 91s 161ms/step - loss: 38.3939 - precision: 0.6551 - recall: 0.7798 - auc: 0.7131 - accuracy: 0.6592 - f_score: 0.7078 - val_loss: 31.8186 - val_precision: 0.9440 - val_recall: 0.6270 - val_auc: 0.6389 - val_accuracy: 0.6263 - val_f_score: 0.7487 - lr: 0.0138
# Epoch 3/45
# 562/562 [==============================] - 89s 159ms/step - loss: 24.3474 - precision: 0.6583 - recall: 0.7932 - auc: 0.7244 - accuracy: 0.6657 - f_score: 0.7152 - val_loss: 17.1172 - val_precision: 0.9145 - val_recall: 0.8154 - val_auc: 0.5044 - val_accuracy: 0.7623 - val_f_score: 0.8593 - lr: 0.0081
# Epoch 4/45
# 562/562 [==============================] - 89s 158ms/step - loss: 11.8478 - precision: 0.6639 - recall: 0.7883 - auc: 0.7326 - accuracy: 0.6699 - f_score: 0.7163 - val_loss: 6.5840 - val_precision: 0.9331 - val_recall: 0.8179 - val_auc: 0.6352 - val_accuracy: 0.7807 - val_f_score: 0.8692 - lr: 0.0030
# Epoch 5/45
# 562/562 [==============================] - 90s 160ms/step - loss: 3.3099 - precision: 0.6719 - recall: 0.7968 - auc: 0.7435 - accuracy: 0.6799 - f_score: 0.7254 - val_loss: 1.0074 - val_precision: 0.9276 - val_recall: 0.8229 - val_auc: 0.6197 - val_accuracy: 0.7801 - val_f_score: 0.8716 - lr: 1.9936e-04
# Epoch 6/45
# 562/562 [==============================] - 89s 158ms/step - loss: 7.9948 - precision: 0.6866 - recall: 0.7867 - auc: 0.7570 - accuracy: 0.6907 - f_score: 0.7296 - val_loss: 9.8575 - val_precision: 0.9243 - val_recall: 0.7996 - val_auc: 0.5947 - val_accuracy: 0.7577 - val_f_score: 0.8550 - lr: 0.0039
# Epoch 7/45
# 562/562 [==============================] - 88s 157ms/step - loss: 9.5897 - precision: 0.6997 - recall: 0.7899 - auc: 0.7713 - accuracy: 0.7032 - f_score: 0.7386 - val_loss: 8.5422 - val_precision: 0.9207 - val_recall: 0.8267 - val_auc: 0.5689 - val_accuracy: 0.7773 - val_f_score: 0.8697 - lr: 0.0034
# Epoch 8/45
# 562/562 [==============================] - 88s 157ms/step - loss: 7.6720 - precision: 0.7023 - recall: 0.7845 - auc: 0.7722 - accuracy: 0.7038 - f_score: 0.7383 - val_loss: 6.7191 - val_precision: 0.9293 - val_recall: 0.8532 - val_auc: 0.6267 - val_accuracy: 0.8071 - val_f_score: 0.8876 - lr: 0.0025
# Epoch 9/45
# 562/562 [==============================] - 88s 156ms/step - loss: 5.1788 - precision: 0.7036 - recall: 0.7868 - auc: 0.7762 - accuracy: 0.7057 - f_score: 0.7400 - val_loss: 3.7861 - val_precision: 0.9289 - val_recall: 0.7410 - val_auc: 0.6168 - val_accuracy: 0.7124 - val_f_score: 0.8218 - lr: 0.0016
# Epoch 10/45
# 562/562 [==============================] - 88s 157ms/step - loss: 2.9803 - precision: 0.7161 - recall: 0.7877 - auc: 0.7827 - accuracy: 0.7165 - f_score: 0.7474 - val_loss: 2.1048 - val_precision: 0.9296 - val_recall: 0.7568 - val_auc: 0.6261 - val_accuracy: 0.7262 - val_f_score: 0.8327 - lr: 6.8920e-04
# Epoch 11/45
# 562/562 [==============================] - 88s 156ms/step - loss: 1.3781 - precision: 0.7184 - recall: 0.7926 - auc: 0.7889 - accuracy: 0.7200 - f_score: 0.7500 - val_loss: 0.8813 - val_precision: 0.9280 - val_recall: 0.7719 - val_auc: 0.6219 - val_accuracy: 0.7377 - val_f_score: 0.8396 - lr: 1.3221e-04
# Epoch 12/45
# 562/562 [==============================] - 91s 161ms/step - loss: 1.4031 - precision: 0.7111 - recall: 0.7781 - auc: 0.7795 - accuracy: 0.7092 - f_score: 0.7400 - val_loss: 2.5489 - val_precision: 0.9271 - val_recall: 0.8255 - val_auc: 0.6322 - val_accuracy: 0.7819 - val_f_score: 0.8721 - lr: 7.9784e-04
# Epoch 13/45
# 562/562 [==============================] - 89s 159ms/step - loss: 2.5549 - precision: 0.7093 - recall: 0.7973 - auc: 0.7845 - accuracy: 0.7139 - f_score: 0.7471 - val_loss: 2.3361 - val_precision: 0.9274 - val_recall: 0.8129 - val_auc: 0.6027 - val_accuracy: 0.7715 - val_f_score: 0.8646 - lr: 7.4857e-04
# Epoch 14/45
# 562/562 [==============================] - 87s 154ms/step - loss: 2.3066 - precision: 0.7130 - recall: 0.7823 - auc: 0.7841 - accuracy: 0.7122 - f_score: 0.7427 - val_loss: 2.3137 - val_precision: 0.9242 - val_recall: 0.7914 - val_auc: 0.6165 - val_accuracy: 0.7509 - val_f_score: 0.8509 - lr: 6.4189e-04
# Epoch 15/45
# 562/562 [==============================] - 87s 154ms/step - loss: 1.9312 - precision: 0.7101 - recall: 0.7934 - auc: 0.7855 - accuracy: 0.7134 - f_score: 0.7466 - val_loss: 1.6207 - val_precision: 0.9263 - val_recall: 0.7845 - val_auc: 0.5997 - val_accuracy: 0.7468 - val_f_score: 0.8481 - lr: 4.9536e-04
# Epoch 16/45
# 562/562 [==============================] - 86s 153ms/step - loss: 1.5116 - precision: 0.7143 - recall: 0.7899 - auc: 0.7845 - accuracy: 0.7157 - f_score: 0.7475 - val_loss: 1.3033 - val_precision: 0.9286 - val_recall: 0.8034 - val_auc: 0.6204 - val_accuracy: 0.7646 - val_f_score: 0.8591 - lr: 3.3312e-04
# Epoch 17/45
# 562/562 [==============================] - 86s 154ms/step - loss: 1.1309 - precision: 0.7179 - recall: 0.7927 - auc: 0.7873 - accuracy: 0.7196 - f_score: 0.7503 - val_loss: 0.9486 - val_precision: 0.9261 - val_recall: 0.7895 - val_auc: 0.6185 - val_accuracy: 0.7509 - val_f_score: 0.8502 - lr: 1.8190e-04
# Epoch 18/45
# 562/562 [==============================] - 86s 153ms/step - loss: 0.8362 - precision: 0.7157 - recall: 0.7859 - auc: 0.7867 - accuracy: 0.7156 - f_score: 0.7458 - val_loss: 0.6987 - val_precision: 0.9284 - val_recall: 0.8009 - val_auc: 0.6196 - val_accuracy: 0.7623 - val_f_score: 0.8581 - lr: 6.6607e-05
# Epoch 19/45
# 562/562 [==============================] - 85s 152ms/step - loss: 0.6466 - precision: 0.7189 - recall: 0.7931 - auc: 0.7884 - accuracy: 0.7206 - f_score: 0.7505 - val_loss: 0.5716 - val_precision: 0.9288 - val_recall: 0.7977 - val_auc: 0.6176 - val_accuracy: 0.7600 - val_f_score: 0.8556 - lr: 6.2298e-06
# Epoch 20/45
# 562/562 [==============================] - 88s 157ms/step - loss: 0.8426 - precision: 0.7134 - recall: 0.7893 - auc: 0.7824 - accuracy: 0.7148 - f_score: 0.7464 - val_loss: 0.9709 - val_precision: 0.9270 - val_recall: 0.7921 - val_auc: 0.6158 - val_accuracy: 0.7537 - val_f_score: 0.8523 - lr: 1.5851e-04
# Epoch 21/45
# 562/562 [==============================] - 88s 157ms/step - loss: 0.9579 - precision: 0.7165 - recall: 0.7943 - auc: 0.7878 - accuracy: 0.7190 - f_score: 0.7501 - val_loss: 0.8930 - val_precision: 0.9285 - val_recall: 0.7933 - val_auc: 0.6129 - val_accuracy: 0.7560 - val_f_score: 0.8525 - lr: 1.4887e-04
# Epoch 22/45
# 562/562 [==============================] - 85s 151ms/step - loss: 0.9197 - precision: 0.7131 - recall: 0.7940 - auc: 0.7853 - accuracy: 0.7160 - f_score: 0.7481 - val_loss: 0.8995 - val_precision: 0.9282 - val_recall: 0.7902 - val_auc: 0.6138 - val_accuracy: 0.7532 - val_f_score: 0.8519 - lr: 1.3131e-04
# Epoch 23/45
# 562/562 [==============================] - 92s 163ms/step - loss: 0.8603 - precision: 0.7132 - recall: 0.7891 - auc: 0.7843 - accuracy: 0.7145 - f_score: 0.7456 - val_loss: 0.8134 - val_precision: 0.9274 - val_recall: 0.7807 - val_auc: 0.6251 - val_accuracy: 0.7445 - val_f_score: 0.8461 - lr: 1.0786e-04
# Epoch 24/45
# 562/562 [==============================] - 90s 160ms/step - loss: 0.7946 - precision: 0.7122 - recall: 0.7936 - auc: 0.7826 - accuracy: 0.7152 - f_score: 0.7477 - val_loss: 0.7504 - val_precision: 0.9295 - val_recall: 0.7813 - val_auc: 0.6232 - val_accuracy: 0.7468 - val_f_score: 0.8474 - lr: 8.1212e-05
# Epoch 25/45
# 562/562 [==============================] - 88s 156ms/step - loss: 0.7261 - precision: 0.7109 - recall: 0.7903 - auc: 0.7841 - accuracy: 0.7130 - f_score: 0.7451 - val_loss: 0.6767 - val_precision: 0.9279 - val_recall: 0.7864 - val_auc: 0.6167 - val_accuracy: 0.7497 - val_f_score: 0.8497 - lr: 5.4423e-05
# Epoch 26/45
# 562/562 [==============================] - 89s 159ms/step - loss: 0.6703 - precision: 0.7137 - recall: 0.7922 - auc: 0.7840 - accuracy: 0.7160 - f_score: 0.7480 - val_loss: 0.6286 - val_precision: 0.9263 - val_recall: 0.7845 - val_auc: 0.6159 - val_accuracy: 0.7468 - val_f_score: 0.8473 - lr: 3.0572e-05
# [0.018323412, 0.013846176, 0.008074781, 0.0029511806, 0.00019936363, 0.0038960932, 0.0033729065, 0.0025260628, 0.0015552015, 0.0006891997, 0.00013221495, 0.0007978394, 0.00074857153, 0.00064188626, 0.00049535715, 0.00033312067, 0.00018190074, 6.660664e-05, 6.229753e-06, 0.00015851014, 0.00014886667, 0.00013131196, 0.00010786255, 8.1212434e-05, 5.4423017e-05, 3.057197e-05]

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
