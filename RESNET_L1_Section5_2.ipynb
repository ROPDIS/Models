# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/RESNET_L1_Section5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

resnet = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.ResNet50V2(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

resnet.add(pretrained_model)

resnet.add(tf.keras.layers.GlobalMaxPooling2D())  # Use GlobalMaxPooling2D
resnet.add(BatchNormalization())  # Add BatchNormalization layer
resnet.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
resnet.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
resnet.add(BatchNormalization())  # Add BatchNormalization layer
resnet.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
resnet.add(tf.keras.layers.Dense(1, activation='sigmoid'))

resnet.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 2, 3, 2048)        23564800
#
#  global_max_pooling2d_1 (Glo  (None, 2048)             0
#  balMaxPooling2D)
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_2 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24,624,641
# Trainable params: 1,054,721
# Non-trainable params: 23,569,920
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

resnet.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=resnet.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3226s 6s/step - loss: 30.1554 - precision: 0.6755 - recall: 0.7715 - auc: 0.7321 - accuracy: 0.6762 - f_score: 0.7147 - val_loss: 25.8519 - val_precision: 0.9103 - val_recall: 0.9653 - val_auc: 0.7081 - val_accuracy: 0.8817 - val_f_score: 0.9361 - lr: 0.0200
# Epoch 2/45
# 562/562 [==============================] - 72s 127ms/step - loss: 26.0793 - precision: 0.6732 - recall: 0.7730 - auc: 0.7377 - accuracy: 0.6745 - f_score: 0.7148 - val_loss: 26.1194 - val_precision: 0.9153 - val_recall: 0.9332 - val_auc: 0.6744 - val_accuracy: 0.8605 - val_f_score: 0.9235 - lr: 0.0200
# Epoch 3/45
# 562/562 [==============================] - 71s 126ms/step - loss: 26.1317 - precision: 0.6654 - recall: 0.7821 - auc: 0.7293 - accuracy: 0.6697 - f_score: 0.7145 - val_loss: 25.8484 - val_precision: 0.9139 - val_recall: 0.9836 - val_auc: 0.7358 - val_accuracy: 0.9007 - val_f_score: 0.9466 - lr: 0.0200
# Epoch 4/45
# 562/562 [==============================] - 72s 127ms/step - loss: 26.1437 - precision: 0.6689 - recall: 0.7825 - auc: 0.7317 - accuracy: 0.6731 - f_score: 0.7167 - val_loss: 25.8304 - val_precision: 0.9114 - val_recall: 0.9918 - val_auc: 0.7155 - val_accuracy: 0.9047 - val_f_score: 0.9495 - lr: 0.0200
# Epoch 5/45
# 562/562 [==============================] - 71s 126ms/step - loss: 26.1544 - precision: 0.6625 - recall: 0.7816 - auc: 0.7313 - accuracy: 0.6668 - f_score: 0.7127 - val_loss: 26.5658 - val_precision: 0.9570 - val_recall: 0.6314 - val_auc: 0.7022 - val_accuracy: 0.6383 - val_f_score: 0.7576 - lr: 0.0200
# Epoch 6/45
# 562/562 [==============================] - 73s 129ms/step - loss: 26.1683 - precision: 0.6683 - recall: 0.7712 - auc: 0.7316 - accuracy: 0.6695 - f_score: 0.7108 - val_loss: 26.0076 - val_precision: 0.9486 - val_recall: 0.7322 - val_auc: 0.7076 - val_accuracy: 0.7199 - val_f_score: 0.8241 - lr: 0.0200
# Epoch 7/45
# 562/562 [==============================] - 75s 133ms/step - loss: 26.1735 - precision: 0.6681 - recall: 0.7749 - auc: 0.7295 - accuracy: 0.6703 - f_score: 0.7131 - val_loss: 25.9709 - val_precision: 0.9160 - val_recall: 0.9212 - val_auc: 0.7421 - val_accuracy: 0.8513 - val_f_score: 0.9175 - lr: 0.0200
# Epoch 8/45
# 562/562 [==============================] - 75s 133ms/step - loss: 26.1721 - precision: 0.6743 - recall: 0.7715 - auc: 0.7373 - accuracy: 0.6752 - f_score: 0.7155 - val_loss: 26.3296 - val_precision: 0.9225 - val_recall: 0.8922 - val_auc: 0.6652 - val_accuracy: 0.8335 - val_f_score: 0.9055 - lr: 0.0200
# Epoch 9/45
# 562/562 [==============================] - 73s 131ms/step - loss: 3.5960 - precision: 0.6849 - recall: 0.7848 - auc: 0.7552 - accuracy: 0.6886 - f_score: 0.7275 - val_loss: 3.1860 - val_precision: 0.9387 - val_recall: 0.7908 - val_auc: 0.6738 - val_accuracy: 0.7623 - val_f_score: 0.8559 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 74s 131ms/step - loss: 3.1789 - precision: 0.6868 - recall: 0.7836 - auc: 0.7569 - accuracy: 0.6899 - f_score: 0.7293 - val_loss: 3.1248 - val_precision: 0.9275 - val_recall: 0.8544 - val_auc: 0.6723 - val_accuracy: 0.8065 - val_f_score: 0.8882 - lr: 0.0020
# Epoch 11/45
# 562/562 [==============================] - 74s 132ms/step - loss: 3.1742 - precision: 0.6940 - recall: 0.7864 - auc: 0.7638 - accuracy: 0.6972 - f_score: 0.7334 - val_loss: 3.0347 - val_precision: 0.9295 - val_recall: 0.8809 - val_auc: 0.6776 - val_accuracy: 0.8307 - val_f_score: 0.9024 - lr: 0.0020
# Epoch 12/45
# 562/562 [==============================] - 75s 134ms/step - loss: 3.1749 - precision: 0.6888 - recall: 0.7877 - auc: 0.7614 - accuracy: 0.6929 - f_score: 0.7314 - val_loss: 3.0912 - val_precision: 0.9367 - val_recall: 0.8393 - val_auc: 0.7101 - val_accuracy: 0.8020 - val_f_score: 0.8837 - lr: 0.0020
# Epoch 13/45
# 562/562 [==============================] - 75s 133ms/step - loss: 0.8958 - precision: 0.7015 - recall: 0.7679 - auc: 0.7647 - accuracy: 0.6980 - f_score: 0.7294 - val_loss: 0.8279 - val_precision: 0.9366 - val_recall: 0.7908 - val_auc: 0.6916 - val_accuracy: 0.7606 - val_f_score: 0.8568 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 74s 132ms/step - loss: 0.8491 - precision: 0.7023 - recall: 0.7809 - auc: 0.7696 - accuracy: 0.7027 - f_score: 0.7356 - val_loss: 0.8023 - val_precision: 0.9369 - val_recall: 0.8141 - val_auc: 0.6891 - val_accuracy: 0.7807 - val_f_score: 0.8682 - lr: 2.0000e-04
# Epoch 15/45
# 562/562 [==============================] - 74s 131ms/step - loss: 0.8570 - precision: 0.6948 - recall: 0.7832 - auc: 0.7621 - accuracy: 0.6969 - f_score: 0.7327 - val_loss: 0.7866 - val_precision: 0.9339 - val_recall: 0.8368 - val_auc: 0.6846 - val_accuracy: 0.7974 - val_f_score: 0.8812 - lr: 2.0000e-04
# Epoch 16/45
# 562/562 [==============================] - 73s 131ms/step - loss: 0.8534 - precision: 0.6934 - recall: 0.7880 - auc: 0.7648 - accuracy: 0.6971 - f_score: 0.7342 - val_loss: 0.7980 - val_precision: 0.9359 - val_recall: 0.8280 - val_auc: 0.6887 - val_accuracy: 0.7916 - val_f_score: 0.8754 - lr: 2.0000e-04
# Epoch 17/45
# 562/562 [==============================] - 75s 133ms/step - loss: 0.6272 - precision: 0.6932 - recall: 0.7785 - auc: 0.7611 - accuracy: 0.6941 - f_score: 0.7300 - val_loss: 0.5698 - val_precision: 0.9352 - val_recall: 0.8280 - val_auc: 0.6896 - val_accuracy: 0.7910 - val_f_score: 0.8756 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 74s 132ms/step - loss: 0.6238 - precision: 0.6910 - recall: 0.7845 - auc: 0.7614 - accuracy: 0.6939 - f_score: 0.7305 - val_loss: 0.5664 - val_precision: 0.9354 - val_recall: 0.8299 - val_auc: 0.6898 - val_accuracy: 0.7928 - val_f_score: 0.8780 - lr: 2.0000e-05
# Epoch 19/45
# 562/562 [==============================] - 74s 131ms/step - loss: 0.6194 - precision: 0.6986 - recall: 0.7920 - auc: 0.7689 - accuracy: 0.7029 - f_score: 0.7389 - val_loss: 0.5663 - val_precision: 0.9364 - val_recall: 0.8255 - val_auc: 0.6899 - val_accuracy: 0.7899 - val_f_score: 0.8760 - lr: 2.0000e-05
# Epoch 20/45
# 562/562 [==============================] - 74s 131ms/step - loss: 0.6195 - precision: 0.6972 - recall: 0.7867 - auc: 0.7674 - accuracy: 0.7001 - f_score: 0.7367 - val_loss: 0.5629 - val_precision: 0.9349 - val_recall: 0.8324 - val_auc: 0.6872 - val_accuracy: 0.7945 - val_f_score: 0.8792 - lr: 2.0000e-05
# Epoch 21/45
# 562/562 [==============================] - 74s 132ms/step - loss: 0.5950 - precision: 0.6954 - recall: 0.7921 - auc: 0.7685 - accuracy: 0.7002 - f_score: 0.7376 - val_loss: 0.5437 - val_precision: 0.9350 - val_recall: 0.8248 - val_auc: 0.6887 - val_accuracy: 0.7882 - val_f_score: 0.8756 - lr: 2.0000e-06
# Epoch 22/45
# 562/562 [==============================] - 74s 132ms/step - loss: 0.5993 - precision: 0.6954 - recall: 0.7880 - auc: 0.7643 - accuracy: 0.6989 - f_score: 0.7357 - val_loss: 0.5404 - val_precision: 0.9349 - val_recall: 0.8324 - val_auc: 0.6894 - val_accuracy: 0.7945 - val_f_score: 0.8789 - lr: 2.0000e-06
# Epoch 23/45
# 562/562 [==============================] - 74s 132ms/step - loss: 0.5950 - precision: 0.6960 - recall: 0.7881 - auc: 0.7678 - accuracy: 0.6995 - f_score: 0.7360 - val_loss: 0.5395 - val_precision: 0.9348 - val_recall: 0.8311 - val_auc: 0.6886 - val_accuracy: 0.7933 - val_f_score: 0.8778 - lr: 2.0000e-06
# Epoch 24/45
# 562/562 [==============================] - 75s 133ms/step - loss: 0.5986 - precision: 0.6929 - recall: 0.7864 - auc: 0.7641 - accuracy: 0.6963 - f_score: 0.7335 - val_loss: 0.5386 - val_precision: 0.9353 - val_recall: 0.8374 - val_auc: 0.6890 - val_accuracy: 0.7991 - val_f_score: 0.8822 - lr: 2.0000e-06
# Epoch 25/45
# 562/562 [==============================] - 75s 134ms/step - loss: 0.5940 - precision: 0.6945 - recall: 0.7844 - auc: 0.7657 - accuracy: 0.6971 - f_score: 0.7332 - val_loss: 0.5415 - val_precision: 0.9351 - val_recall: 0.8261 - val_auc: 0.6895 - val_accuracy: 0.7893 - val_f_score: 0.8729 - lr: 2.0000e-07
# Epoch 26/45
# 562/562 [==============================] - 77s 138ms/step - loss: 0.5946 - precision: 0.6945 - recall: 0.7846 - auc: 0.7663 - accuracy: 0.6971 - f_score: 0.7342 - val_loss: 0.5379 - val_precision: 0.9355 - val_recall: 0.8311 - val_auc: 0.6875 - val_accuracy: 0.7939 - val_f_score: 0.8784 - lr: 2.0000e-07
# Epoch 27/45
# 562/562 [==============================] - 76s 135ms/step - loss: 0.5968 - precision: 0.6957 - recall: 0.7862 - auc: 0.7649 - accuracy: 0.6986 - f_score: 0.7347 - val_loss: 0.5442 - val_precision: 0.9365 - val_recall: 0.8179 - val_auc: 0.6892 - val_accuracy: 0.7836 - val_f_score: 0.8719 - lr: 2.0000e-07
# Epoch 28/45
# 562/562 [==============================] - 76s 135ms/step - loss: 0.5974 - precision: 0.6959 - recall: 0.7857 - auc: 0.7643 - accuracy: 0.6986 - f_score: 0.7347 - val_loss: 0.5346 - val_precision: 0.9342 - val_recall: 0.8406 - val_auc: 0.6896 - val_accuracy: 0.8008 - val_f_score: 0.8829 - lr: 2.0000e-07
# Epoch 29/45
# 562/562 [==============================] - 77s 137ms/step - loss: 0.5985 - precision: 0.6910 - recall: 0.7827 - auc: 0.7614 - accuracy: 0.6934 - f_score: 0.7309 - val_loss: 0.5421 - val_precision: 0.9351 - val_recall: 0.8267 - val_auc: 0.6898 - val_accuracy: 0.7899 - val_f_score: 0.8760 - lr: 2.0000e-08

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
