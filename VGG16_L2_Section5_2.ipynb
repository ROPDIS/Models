# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/VGG16_L2_Section5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L2

VGG = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(60,80,3),
    pooling=None)

for layer in pretrained_model.layers:
    layer.trainable = False

VGG.add(pretrained_model)

VGG.add(tf.keras.layers.Flatten())
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2, activity_regularizer=L2(0.01))) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L2(0.01)))
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2, activity_regularizer=L2(0.01))) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(1, activation='sigmoid'))

VGG.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 2, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  batch_normalization_3 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 15,246,145
# Trainable params: 528,385
# Non-trainable params: 14,717,760
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

VGG.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history = VGG.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=15,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 1818s 3s/step - loss: 1.5394 - precision: 0.7366 - recall: 0.7726 - auc: 0.7887 - accuracy: 0.7278 - f_score: 0.7505 - val_loss: 0.5935 - val_precision: 0.9627 - val_recall: 0.8135 - val_auc: 0.8163 - val_accuracy: 0.8014 - val_f_score: 0.8800 - lr: 0.0200
# Epoch 2/45
# 562/562 [==============================] - 97s 173ms/step - loss: 0.6513 - precision: 0.7410 - recall: 0.7848 - auc: 0.8030 - accuracy: 0.7354 - f_score: 0.7586 - val_loss: 1.0368 - val_precision: 0.9771 - val_recall: 0.3226 - val_auc: 0.7730 - val_accuracy: 0.3760 - val_f_score: 0.4826 - lr: 0.0200
# Epoch 3/45
# 562/562 [==============================] - 98s 174ms/step - loss: 0.6446 - precision: 0.7426 - recall: 0.7915 - auc: 0.8061 - accuracy: 0.7391 - f_score: 0.7627 - val_loss: 1.1490 - val_precision: 0.9767 - val_recall: 0.2911 - val_auc: 0.7438 - val_accuracy: 0.3479 - val_f_score: 0.4444 - lr: 0.0200
# Epoch 4/45
# 562/562 [==============================] - 97s 173ms/step - loss: 0.6470 - precision: 0.7397 - recall: 0.7908 - auc: 0.8032 - accuracy: 0.7366 - f_score: 0.7611 - val_loss: 0.6622 - val_precision: 0.9755 - val_recall: 0.7013 - val_auc: 0.8140 - val_accuracy: 0.7118 - val_f_score: 0.8135 - lr: 0.0200
# Epoch 5/45
# 562/562 [==============================] - 97s 173ms/step - loss: 0.6554 - precision: 0.7443 - recall: 0.7833 - auc: 0.8030 - accuracy: 0.7375 - f_score: 0.7594 - val_loss: 0.7451 - val_precision: 0.9644 - val_recall: 0.6144 - val_auc: 0.7293 - val_accuracy: 0.6280 - val_f_score: 0.7462 - lr: 0.0200
# Epoch 6/45
# 562/562 [==============================] - 97s 172ms/step - loss: 0.5436 - precision: 0.7611 - recall: 0.8121 - auc: 0.8323 - accuracy: 0.7607 - f_score: 0.7818 - val_loss: 0.7055 - val_precision: 0.9740 - val_recall: 0.5892 - val_auc: 0.7708 - val_accuracy: 0.6114 - val_f_score: 0.7307 - lr: 0.0020
# Epoch 7/45
# 562/562 [==============================] - 96s 171ms/step - loss: 0.5262 - precision: 0.7736 - recall: 0.8091 - auc: 0.8379 - accuracy: 0.7688 - f_score: 0.7885 - val_loss: 0.7717 - val_precision: 0.9771 - val_recall: 0.5388 - val_auc: 0.7697 - val_accuracy: 0.5683 - val_f_score: 0.6864 - lr: 0.0020
# Epoch 8/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.5212 - precision: 0.7758 - recall: 0.8113 - auc: 0.8440 - accuracy: 0.7713 - f_score: 0.7897 - val_loss: 0.7613 - val_precision: 0.9845 - val_recall: 0.5614 - val_auc: 0.8056 - val_accuracy: 0.5924 - val_f_score: 0.7113 - lr: 0.0020
# Epoch 9/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.5270 - precision: 0.7691 - recall: 0.8096 - auc: 0.8391 - accuracy: 0.7657 - f_score: 0.7862 - val_loss: 0.7218 - val_precision: 0.9731 - val_recall: 0.6163 - val_auc: 0.8003 - val_accuracy: 0.6349 - val_f_score: 0.7513 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.5097 - precision: 0.7855 - recall: 0.8145 - auc: 0.8498 - accuracy: 0.7796 - f_score: 0.7971 - val_loss: 0.8132 - val_precision: 0.9803 - val_recall: 0.5318 - val_auc: 0.7880 - val_accuracy: 0.5637 - val_f_score: 0.6834 - lr: 2.0000e-04
# Epoch 11/45
# 562/562 [==============================] - 96s 171ms/step - loss: 0.5010 - precision: 0.7810 - recall: 0.8232 - auc: 0.8525 - accuracy: 0.7797 - f_score: 0.7989 - val_loss: 0.8410 - val_precision: 0.9819 - val_recall: 0.5135 - val_auc: 0.7821 - val_accuracy: 0.5482 - val_f_score: 0.6684 - lr: 2.0000e-04
# Epoch 12/45
# 562/562 [==============================] - 98s 174ms/step - loss: 0.4974 - precision: 0.7856 - recall: 0.8227 - auc: 0.8536 - accuracy: 0.7829 - f_score: 0.8006 - val_loss: 0.7424 - val_precision: 0.9799 - val_recall: 0.5829 - val_auc: 0.7892 - val_accuracy: 0.6091 - val_f_score: 0.7270 - lr: 2.0000e-04
# Epoch 13/45
# 562/562 [==============================] - 98s 174ms/step - loss: 0.4919 - precision: 0.7846 - recall: 0.8269 - auc: 0.8563 - accuracy: 0.7838 - f_score: 0.8026 - val_loss: 0.7713 - val_precision: 0.9823 - val_recall: 0.5602 - val_auc: 0.8038 - val_accuracy: 0.5901 - val_f_score: 0.7104 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 98s 174ms/step - loss: 0.4919 - precision: 0.7889 - recall: 0.8160 - auc: 0.8561 - accuracy: 0.7825 - f_score: 0.7996 - val_loss: 0.7837 - val_precision: 0.9820 - val_recall: 0.5495 - val_auc: 0.8026 - val_accuracy: 0.5804 - val_f_score: 0.7006 - lr: 2.0000e-05
# Epoch 15/45
# 562/562 [==============================] - 97s 172ms/step - loss: 0.4947 - precision: 0.7888 - recall: 0.8147 - auc: 0.8540 - accuracy: 0.7820 - f_score: 0.7997 - val_loss: 0.7839 - val_precision: 0.9821 - val_recall: 0.5539 - val_auc: 0.8011 - val_accuracy: 0.5844 - val_f_score: 0.7049 - lr: 2.0000e-05
# Epoch 16/45
# 562/562 [==============================] - 99s 176ms/step - loss: 0.4868 - precision: 0.7865 - recall: 0.8245 - auc: 0.8592 - accuracy: 0.7843 - f_score: 0.8024 - val_loss: 0.7871 - val_precision: 0.9821 - val_recall: 0.5532 - val_auc: 0.8012 - val_accuracy: 0.5838 - val_f_score: 0.7036 - lr: 2.0000e-05

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = VGG.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 55/55 [==============================] - 7s 124ms/step
# AUC: 0.5413948004959652
