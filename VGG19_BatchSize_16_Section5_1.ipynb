# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/VGG19_BatchSize_16_Section5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=16,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 16,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
VGG = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_shape=(60,80,3),
    pooling=None)

for layer in pretrained_model.layers:
    layer.trainable = False

VGG.add(pretrained_model)

VGG.add(tf.keras.layers.Flatten())  # Use GlobalMaxPooling2D
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(512, activation='relu'))
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(1, activation='sigmoid'))

VGG.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 1, 2, 512)         20024384
#
#  flatten (Flatten)           (None, 1024)              0
#
#  batch_normalization_4 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,555,841
# Trainable params: 528,385
# Non-trainable params: 20,027,456
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.002)

VGG.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history = VGG.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 1124/1124 [==============================] - 122s 106ms/step - loss: 0.5642 - precision: 0.7450 - recall: 0.7690 - auc: 0.8002 - accuracy: 0.7329 - f_score: 0.7492 - val_loss: 0.7834 - val_precision: 0.9843 - val_recall: 0.5142 - val_auc: 0.8440 - val_accuracy: 0.5499 - val_f_score: 0.6655 - lr: 0.0020
# Epoch 2/45
# 1124/1124 [==============================] - 108s 96ms/step - loss: 0.5051 - precision: 0.7685 - recall: 0.7914 - auc: 0.8333 - accuracy: 0.7584 - f_score: 0.7736 - val_loss: 0.6933 - val_precision: 0.9887 - val_recall: 0.6049 - val_auc: 0.8865 - val_accuracy: 0.6338 - val_f_score: 0.7401 - lr: 0.0020
# Epoch 3/45
# 1124/1124 [==============================] - 108s 96ms/step - loss: 0.4980 - precision: 0.7731 - recall: 0.8007 - auc: 0.8380 - accuracy: 0.7653 - f_score: 0.7802 - val_loss: 0.8487 - val_precision: 0.9796 - val_recall: 0.5444 - val_auc: 0.7773 - val_accuracy: 0.5746 - val_f_score: 0.6903 - lr: 0.0020
# Epoch 4/45
# 1124/1124 [==============================] - 107s 95ms/step - loss: 0.4889 - precision: 0.7814 - recall: 0.8026 - auc: 0.8448 - accuracy: 0.7720 - f_score: 0.7858 - val_loss: 1.1856 - val_precision: 0.9870 - val_recall: 0.2401 - val_auc: 0.8510 - val_accuracy: 0.3048 - val_f_score: 0.3743 - lr: 0.0020
# Epoch 5/45
# 1124/1124 [==============================] - 106s 94ms/step - loss: 0.4845 - precision: 0.7825 - recall: 0.8033 - auc: 0.8471 - accuracy: 0.7731 - f_score: 0.7866 - val_loss: 1.0119 - val_precision: 0.9909 - val_recall: 0.4108 - val_auc: 0.8695 - val_accuracy: 0.4598 - val_f_score: 0.5689 - lr: 0.0020
# Epoch 6/45
# 1124/1124 [==============================] - 106s 94ms/step - loss: 0.4810 - precision: 0.7808 - recall: 0.8019 - auc: 0.8494 - accuracy: 0.7713 - f_score: 0.7855 - val_loss: 0.8040 - val_precision: 0.9882 - val_recall: 0.5299 - val_auc: 0.8700 - val_accuracy: 0.5660 - val_f_score: 0.6809 - lr: 0.0020
# Epoch 7/45
# 1124/1124 [==============================] - 107s 95ms/step - loss: 0.4645 - precision: 0.7958 - recall: 0.8018 - auc: 0.8605 - accuracy: 0.7817 - f_score: 0.7935 - val_loss: 0.9029 - val_precision: 0.9903 - val_recall: 0.4512 - val_auc: 0.8595 - val_accuracy: 0.4960 - val_f_score: 0.6084 - lr: 2.0000e-04
# Epoch 8/45
# 1124/1124 [==============================] - 106s 95ms/step - loss: 0.4582 - precision: 0.7958 - recall: 0.8150 - auc: 0.8644 - accuracy: 0.7870 - f_score: 0.7990 - val_loss: 1.0091 - val_precision: 0.9921 - val_recall: 0.3976 - val_auc: 0.8669 - val_accuracy: 0.4483 - val_f_score: 0.5558 - lr: 2.0000e-04
# Epoch 9/45
# 1124/1124 [==============================] - 105s 93ms/step - loss: 0.4572 - precision: 0.7951 - recall: 0.8077 - auc: 0.8646 - accuracy: 0.7836 - f_score: 0.7956 - val_loss: 0.8372 - val_precision: 0.9897 - val_recall: 0.4852 - val_auc: 0.8766 - val_accuracy: 0.5264 - val_f_score: 0.6410 - lr: 2.0000e-04
# Epoch 10/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4554 - precision: 0.7982 - recall: 0.8169 - auc: 0.8664 - accuracy: 0.7894 - f_score: 0.8023 - val_loss: 0.9156 - val_precision: 0.9889 - val_recall: 0.4499 - val_auc: 0.8662 - val_accuracy: 0.4943 - val_f_score: 0.6060 - lr: 2.0000e-04
# Epoch 11/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4525 - precision: 0.8062 - recall: 0.8116 - auc: 0.8679 - accuracy: 0.7928 - f_score: 0.8024 - val_loss: 0.9132 - val_precision: 0.9891 - val_recall: 0.4556 - val_auc: 0.8665 - val_accuracy: 0.4994 - val_f_score: 0.6124 - lr: 2.0000e-05
# Epoch 12/45
# 1124/1124 [==============================] - 105s 93ms/step - loss: 0.4499 - precision: 0.8012 - recall: 0.8136 - auc: 0.8695 - accuracy: 0.7902 - f_score: 0.8013 - val_loss: 0.9190 - val_precision: 0.9889 - val_recall: 0.4480 - val_auc: 0.8659 - val_accuracy: 0.4925 - val_f_score: 0.6056 - lr: 2.0000e-05
# Epoch 13/45
# 1124/1124 [==============================] - 104s 92ms/step - loss: 0.4484 - precision: 0.8049 - recall: 0.8168 - auc: 0.8704 - accuracy: 0.7940 - f_score: 0.8050 - val_loss: 0.9323 - val_precision: 0.9902 - val_recall: 0.4449 - val_auc: 0.8668 - val_accuracy: 0.4902 - val_f_score: 0.6020 - lr: 2.0000e-05
# Epoch 14/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4524 - precision: 0.7965 - recall: 0.8179 - auc: 0.8678 - accuracy: 0.7887 - f_score: 0.8009 - val_loss: 0.9401 - val_precision: 0.9916 - val_recall: 0.4442 - val_auc: 0.8677 - val_accuracy: 0.4902 - val_f_score: 0.6006 - lr: 2.0000e-05
# Epoch 15/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4534 - precision: 0.8005 - recall: 0.8140 - auc: 0.8672 - accuracy: 0.7899 - f_score: 0.8016 - val_loss: 0.9161 - val_precision: 0.9903 - val_recall: 0.4499 - val_auc: 0.8680 - val_accuracy: 0.4948 - val_f_score: 0.6016 - lr: 2.0000e-06
# Epoch 16/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4525 - precision: 0.7999 - recall: 0.8159 - auc: 0.8678 - accuracy: 0.7902 - f_score: 0.8020 - val_loss: 0.9341 - val_precision: 0.9915 - val_recall: 0.4405 - val_auc: 0.8659 - val_accuracy: 0.4868 - val_f_score: 0.5964 - lr: 2.0000e-06
# Epoch 17/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4534 - precision: 0.7991 - recall: 0.8131 - auc: 0.8674 - accuracy: 0.7885 - f_score: 0.8010 - val_loss: 0.9340 - val_precision: 0.9915 - val_recall: 0.4417 - val_auc: 0.8644 - val_accuracy: 0.4879 - val_f_score: 0.5972 - lr: 2.0000e-06
# Epoch 18/45
# 1124/1124 [==============================] - 104s 93ms/step - loss: 0.4519 - precision: 0.8011 - recall: 0.8188 - auc: 0.8686 - accuracy: 0.7922 - f_score: 0.8037 - val_loss: 0.9694 - val_precision: 0.9913 - val_recall: 0.4310 - val_auc: 0.8661 - val_accuracy: 0.4782 - val_f_score: 0.5908 - lr: 2.0000e-06
# Epoch 19/45
# 1124/1124 [==============================] - 105s 93ms/step - loss: 0.4481 - precision: 0.7977 - recall: 0.8155 - auc: 0.8705 - accuracy: 0.7885 - f_score: 0.8020 - val_loss: 0.8960 - val_precision: 0.9892 - val_recall: 0.4612 - val_auc: 0.8664 - val_accuracy: 0.5046 - val_f_score: 0.6167 - lr: 2.0000e-07
# Epoch 20/45
# 1124/1124 [==============================] - 105s 94ms/step - loss: 0.4505 - precision: 0.7986 - recall: 0.8182 - auc: 0.8688 - accuracy: 0.7903 - f_score: 0.8026 - val_loss: 0.9227 - val_precision: 0.9902 - val_recall: 0.4449 - val_auc: 0.8689 - val_accuracy: 0.4902 - val_f_score: 0.6004 - lr: 2.0000e-07
# Epoch 21/45
# 1124/1124 [==============================] - 107s 95ms/step - loss: 0.4538 - precision: 0.7999 - recall: 0.8165 - auc: 0.8668 - accuracy: 0.7904 - f_score: 0.8026 - val_loss: 0.9156 - val_precision: 0.9904 - val_recall: 0.4531 - val_auc: 0.8688 - val_accuracy: 0.4977 - val_f_score: 0.6130 - lr: 2.0000e-07
# Epoch 22/45
# 1124/1124 [==============================] - 113s 100ms/step - loss: 0.4584 - precision: 0.7952 - recall: 0.8171 - auc: 0.8639 - accuracy: 0.7874 - f_score: 0.7987 - val_loss: 0.9066 - val_precision: 0.9903 - val_recall: 0.4524 - val_auc: 0.8662 - val_accuracy: 0.4971 - val_f_score: 0.6077 - lr: 2.0000e-07
# Epoch 23/45
# 1124/1124 [==============================] - 114s 102ms/step - loss: 0.4579 - precision: 0.7978 - recall: 0.8156 - auc: 0.8643 - accuracy: 0.7886 - f_score: 0.8011 - val_loss: 0.9704 - val_precision: 0.9911 - val_recall: 0.4190 - val_auc: 0.8626 - val_accuracy: 0.4673 - val_f_score: 0.5754 - lr: 2.0000e-08
# Epoch 24/45
# 1124/1124 [==============================] - 111s 99ms/step - loss: 0.4580 - precision: 0.7979 - recall: 0.8143 - auc: 0.8651 - accuracy: 0.7882 - f_score: 0.7997 - val_loss: 0.9440 - val_precision: 0.9901 - val_recall: 0.4417 - val_auc: 0.8655 - val_accuracy: 0.4874 - val_f_score: 0.5971 - lr: 2.0000e-08
# Epoch 25/45
# 1124/1124 [==============================] - 107s 95ms/step - loss: 0.4517 - precision: 0.8043 - recall: 0.8232 - auc: 0.8688 - accuracy: 0.7962 - f_score: 0.8076 - val_loss: 0.9740 - val_precision: 0.9910 - val_recall: 0.4171 - val_auc: 0.8645 - val_accuracy: 0.4656 - val_f_score: 0.5745 - lr: 2.0000e-08
# Epoch 26/45
# 1124/1124 [==============================] - 107s 95ms/step - loss: 0.4473 - precision: 0.8036 - recall: 0.8180 - auc: 0.8711 - accuracy: 0.7937 - f_score: 0.8061 - val_loss: 0.9022 - val_precision: 0.9903 - val_recall: 0.4499 - val_auc: 0.8645 - val_accuracy: 0.4948 - val_f_score: 0.6059 - lr: 2.0000e-08
# Epoch 27/45
# 1124/1124 [==============================] - 107s 95ms/step - loss: 0.4529 - precision: 0.7984 - recall: 0.8189 - auc: 0.8677 - accuracy: 0.7904 - f_score: 0.8027 - val_loss: 0.9483 - val_precision: 0.9914 - val_recall: 0.4373 - val_auc: 0.8684 - val_accuracy: 0.4839 - val_f_score: 0.5937 - lr: 2.0000e-09

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = VGG.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 109/109 [==============================] - 9s 79ms/step
# AUC: 0.45595869666849603
