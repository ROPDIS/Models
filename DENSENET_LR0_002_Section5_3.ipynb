# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_LR0_002_Section5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.Flatten())
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  flatten (Flatten)           (None, 3840)              0
#
#  batch_normalization (BatchN  (None, 3840)             15360
#  ormalization)
#
#  dropout (Dropout)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,306,497
# Trainable params: 1,975,809
# Non-trainable params: 18,330,688
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.002)

dense.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 1877s 3s/step - loss: 20.1850 - precision: 0.7121 - recall: 0.7792 - auc: 0.7671 - accuracy: 0.7104 - f_score: 0.7411 - val_loss: 5.5425 - val_precision: 0.9348 - val_recall: 0.8765 - val_auc: 0.7156 - val_accuracy: 0.8318 - val_f_score: 0.9023 - lr: 0.0020
# Epoch 2/45
# 562/562 [==============================] - 82s 146ms/step - loss: 5.2078 - precision: 0.7344 - recall: 0.8046 - auc: 0.8054 - accuracy: 0.7372 - f_score: 0.7649 - val_loss: 4.9800 - val_precision: 0.9364 - val_recall: 0.9282 - val_auc: 0.7714 - val_accuracy: 0.8772 - val_f_score: 0.9309 - lr: 0.0020
# Epoch 3/45
# 562/562 [==============================] - 81s 145ms/step - loss: 5.1498 - precision: 0.7267 - recall: 0.7912 - auc: 0.7960 - accuracy: 0.7264 - f_score: 0.7534 - val_loss: 5.1014 - val_precision: 0.9451 - val_recall: 0.8670 - val_auc: 0.7731 - val_accuracy: 0.8330 - val_f_score: 0.9030 - lr: 0.0020
# Epoch 4/45
# 562/562 [==============================] - 82s 145ms/step - loss: 5.1871 - precision: 0.7256 - recall: 0.8033 - auc: 0.7951 - accuracy: 0.7295 - f_score: 0.7596 - val_loss: 5.1098 - val_precision: 0.9514 - val_recall: 0.8393 - val_auc: 0.8268 - val_accuracy: 0.8146 - val_f_score: 0.8897 - lr: 0.0020
# Epoch 5/45
# 562/562 [==============================] - 80s 143ms/step - loss: 5.2093 - precision: 0.7281 - recall: 0.7931 - auc: 0.7945 - accuracy: 0.7282 - f_score: 0.7561 - val_loss: 5.1699 - val_precision: 0.9642 - val_recall: 0.7984 - val_auc: 0.8384 - val_accuracy: 0.7893 - val_f_score: 0.8716 - lr: 0.0020
# Epoch 6/45
# 562/562 [==============================] - 82s 146ms/step - loss: 5.2240 - precision: 0.7225 - recall: 0.7950 - auc: 0.7913 - accuracy: 0.7242 - f_score: 0.7537 - val_loss: 5.1416 - val_precision: 0.9513 - val_recall: 0.8500 - val_auc: 0.8059 - val_accuracy: 0.8238 - val_f_score: 0.8952 - lr: 0.0020
# Epoch 7/45
# 562/562 [==============================] - 82s 146ms/step - loss: 1.1302 - precision: 0.7290 - recall: 0.8087 - auc: 0.8029 - accuracy: 0.7341 - f_score: 0.7634 - val_loss: 0.9916 - val_precision: 0.9496 - val_recall: 0.8544 - val_auc: 0.7979 - val_accuracy: 0.8261 - val_f_score: 0.8982 - lr: 2.0000e-04
# Epoch 8/45
# 562/562 [==============================] - 84s 148ms/step - loss: 1.0577 - precision: 0.7292 - recall: 0.8040 - auc: 0.8029 - accuracy: 0.7328 - f_score: 0.7617 - val_loss: 0.9964 - val_precision: 0.9502 - val_recall: 0.8425 - val_auc: 0.7890 - val_accuracy: 0.8163 - val_f_score: 0.8917 - lr: 2.0000e-04
# Epoch 9/45
# 562/562 [==============================] - 81s 145ms/step - loss: 1.0533 - precision: 0.7376 - recall: 0.8037 - auc: 0.8080 - accuracy: 0.7395 - f_score: 0.7660 - val_loss: 0.9834 - val_precision: 0.9542 - val_recall: 0.8267 - val_auc: 0.8097 - val_accuracy: 0.8060 - val_f_score: 0.8838 - lr: 2.0000e-04
# Epoch 10/45
# 562/562 [==============================] - 81s 145ms/step - loss: 1.0544 - precision: 0.7358 - recall: 0.8016 - auc: 0.8060 - accuracy: 0.7372 - f_score: 0.7645 - val_loss: 0.9689 - val_precision: 0.9487 - val_recall: 0.8513 - val_auc: 0.8036 - val_accuracy: 0.8226 - val_f_score: 0.8958 - lr: 2.0000e-04
# Epoch 11/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.6244 - precision: 0.7405 - recall: 0.8066 - auc: 0.8098 - accuracy: 0.7427 - f_score: 0.7690 - val_loss: 0.5389 - val_precision: 0.9490 - val_recall: 0.8557 - val_auc: 0.8049 - val_accuracy: 0.8266 - val_f_score: 0.8985 - lr: 2.0000e-05
# Epoch 12/45
# 562/562 [==============================] - 82s 146ms/step - loss: 0.6203 - precision: 0.7320 - recall: 0.8021 - auc: 0.8059 - accuracy: 0.7343 - f_score: 0.7619 - val_loss: 0.5368 - val_precision: 0.9485 - val_recall: 0.8595 - val_auc: 0.8056 - val_accuracy: 0.8295 - val_f_score: 0.9008 - lr: 2.0000e-05
# Epoch 13/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.6230 - precision: 0.7358 - recall: 0.8012 - auc: 0.8038 - accuracy: 0.7371 - f_score: 0.7644 - val_loss: 0.5394 - val_precision: 0.9483 - val_recall: 0.8551 - val_auc: 0.8041 - val_accuracy: 0.8255 - val_f_score: 0.8988 - lr: 2.0000e-05
# Epoch 14/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.6203 - precision: 0.7386 - recall: 0.8021 - auc: 0.8075 - accuracy: 0.7396 - f_score: 0.7660 - val_loss: 0.5397 - val_precision: 0.9484 - val_recall: 0.8570 - val_auc: 0.8004 - val_accuracy: 0.8272 - val_f_score: 0.8991 - lr: 2.0000e-05
# Epoch 15/45
# 562/562 [==============================] - 82s 147ms/step - loss: 0.5772 - precision: 0.7378 - recall: 0.7994 - auc: 0.8061 - accuracy: 0.7381 - f_score: 0.7635 - val_loss: 0.5036 - val_precision: 0.9492 - val_recall: 0.8469 - val_auc: 0.8012 - val_accuracy: 0.8192 - val_f_score: 0.8939 - lr: 2.0000e-06
# Epoch 16/45
# 562/562 [==============================] - 81s 145ms/step - loss: 0.5747 - precision: 0.7371 - recall: 0.8046 - auc: 0.8083 - accuracy: 0.7393 - f_score: 0.7656 - val_loss: 0.4955 - val_precision: 0.9485 - val_recall: 0.8595 - val_auc: 0.7995 - val_accuracy: 0.8295 - val_f_score: 0.8998 - lr: 2.0000e-06
# Epoch 17/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.5704 - precision: 0.7398 - recall: 0.8103 - auc: 0.8132 - accuracy: 0.7435 - f_score: 0.7704 - val_loss: 0.4919 - val_precision: 0.9454 - val_recall: 0.8626 - val_auc: 0.7962 - val_accuracy: 0.8295 - val_f_score: 0.8992 - lr: 2.0000e-06
# Epoch 18/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.5777 - precision: 0.7323 - recall: 0.7987 - auc: 0.8048 - accuracy: 0.7334 - f_score: 0.7608 - val_loss: 0.4986 - val_precision: 0.9482 - val_recall: 0.8532 - val_auc: 0.7979 - val_accuracy: 0.8238 - val_f_score: 0.8956 - lr: 2.0000e-06
# Epoch 19/45
# 562/562 [==============================] - 81s 145ms/step - loss: 0.5731 - precision: 0.7362 - recall: 0.8011 - auc: 0.8059 - accuracy: 0.7373 - f_score: 0.7641 - val_loss: 0.5014 - val_precision: 0.9491 - val_recall: 0.8463 - val_auc: 0.8007 - val_accuracy: 0.8186 - val_f_score: 0.8943 - lr: 2.0000e-07
# Epoch 20/45
# 562/562 [==============================] - 81s 143ms/step - loss: 0.5699 - precision: 0.7377 - recall: 0.8028 - auc: 0.8085 - accuracy: 0.7392 - f_score: 0.7662 - val_loss: 0.4940 - val_precision: 0.9482 - val_recall: 0.8538 - val_auc: 0.8028 - val_accuracy: 0.8243 - val_f_score: 0.8982 - lr: 2.0000e-07
# Epoch 21/45
# 562/562 [==============================] - 80s 143ms/step - loss: 0.5704 - precision: 0.7356 - recall: 0.8047 - auc: 0.8089 - accuracy: 0.7382 - f_score: 0.7659 - val_loss: 0.4993 - val_precision: 0.9498 - val_recall: 0.8456 - val_auc: 0.8028 - val_accuracy: 0.8186 - val_f_score: 0.8925 - lr: 2.0000e-07
# Epoch 22/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.5710 - precision: 0.7397 - recall: 0.8047 - auc: 0.8079 - accuracy: 0.7414 - f_score: 0.7680 - val_loss: 0.5052 - val_precision: 0.9516 - val_recall: 0.8431 - val_auc: 0.8018 - val_accuracy: 0.8180 - val_f_score: 0.8918 - lr: 2.0000e-07
# Epoch 23/45
# 562/562 [==============================] - 83s 147ms/step - loss: 0.5718 - precision: 0.7344 - recall: 0.7969 - auc: 0.8053 - accuracy: 0.7345 - f_score: 0.7612 - val_loss: 0.4977 - val_precision: 0.9506 - val_recall: 0.8481 - val_auc: 0.8024 - val_accuracy: 0.8215 - val_f_score: 0.8946 - lr: 2.0000e-08
# Epoch 24/45
# 562/562 [==============================] - 84s 149ms/step - loss: 0.5754 - precision: 0.7352 - recall: 0.8007 - auc: 0.8036 - accuracy: 0.7365 - f_score: 0.7637 - val_loss: 0.5030 - val_precision: 0.9504 - val_recall: 0.8444 - val_auc: 0.8029 - val_accuracy: 0.8180 - val_f_score: 0.8912 - lr: 2.0000e-08
# Epoch 25/45
# 562/562 [==============================] - 85s 151ms/step - loss: 0.5693 - precision: 0.7373 - recall: 0.8041 - auc: 0.8091 - accuracy: 0.7393 - f_score: 0.7664 - val_loss: 0.4922 - val_precision: 0.9488 - val_recall: 0.8526 - val_auc: 0.8047 - val_accuracy: 0.8238 - val_f_score: 0.8972 - lr: 2.0000e-08
# Epoch 26/45
# 562/562 [==============================] - 83s 148ms/step - loss: 0.5668 - precision: 0.7398 - recall: 0.8009 - auc: 0.8106 - accuracy: 0.7402 - f_score: 0.7662 - val_loss: 0.4965 - val_precision: 0.9493 - val_recall: 0.8494 - val_auc: 0.8015 - val_accuracy: 0.8215 - val_f_score: 0.8926 - lr: 2.0000e-08
# Epoch 27/45
# 562/562 [==============================] - 84s 150ms/step - loss: 0.5688 - precision: 0.7342 - recall: 0.8062 - auc: 0.8094 - accuracy: 0.7376 - f_score: 0.7657 - val_loss: 0.4995 - val_precision: 0.9486 - val_recall: 0.8481 - val_auc: 0.7985 - val_accuracy: 0.8197 - val_f_score: 0.8939 - lr: 2.0000e-09

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
