# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/RESNET_LinearwarmupwithcosineannealingwithRestart_Section5_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
# !pip install tensorflow==2.13
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC
# Out:
# Collecting tensorflow==2.13
#   Downloading tensorflow-2.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (524.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.1/524.1 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.57.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (3.9.0)
# Collecting keras<2.14,>=2.13.1 (from tensorflow==2.13)
#   Downloading keras-2.13.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.3 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.16.0)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow==2.13)
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 105.2 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow==2.13)
#   Downloading tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.8/440.8 kB 43.7 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (2.3.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow==2.13)
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.13) (0.33.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.13) (0.41.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (2.17.3)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow==2.13)
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow==2.13) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow==2.13) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow==2.13) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow==2.13) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow==2.13) (3.2.2)
# Installing collected packages: typing-extensions, tensorflow-estimator, keras, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.0
#     Uninstalling tensorboard-2.12.0:
#       Successfully uninstalled tensorboard-2.12.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# orbax-checkpoint 0.3.4 requires jax>=0.4.9, but you have jax 0.3.25 which is incompatible.
# pydantic 2.2.0 requires typing-extensions>=4.6.1, but you have typing-extensions 4.5.0 which is incompatible.
# pydantic-core 2.6.0 requires typing-extensions!=4.7.0,>=4.6.0, but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed google-auth-oauthlib-1.0.0 keras-2.13.1 tensorboard-2.13.0 tensorflow-2.13.0 tensorflow-estimator-2.13.0 typing-extensions-4.5.0

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

resnet = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.ResNet50V2(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

resnet.add(pretrained_model)

resnet.add(tf.keras.layers.GlobalMaxPooling2D())  # Use GlobalMaxPooling2D
resnet.add(BatchNormalization())  # Add BatchNormalization layer
resnet.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
resnet.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
resnet.add(BatchNormalization())  # Add BatchNormalization layer
resnet.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
resnet.add(tf.keras.layers.Dense(1, activation='sigmoid'))

resnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 2, 3, 2048)        23564800
#
#  global_max_pooling2d (Glob  (None, 2048)              0
#  alMaxPooling2D)
#
#  batch_normalization (Batch  (None, 2048)              8192
#  Normalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24624641 (93.94 MB)
# Trainable params: 1054721 (4.02 MB)
# Non-trainable params: 23569920 (89.91 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import PolynomialDecay, CosineDecay
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping

first_decay_steps=3000
initial_learning_rate = 0.02

lr_warmup_decayed_fn = tf.keras.optimizers.schedules.CosineDecayRestarts(
    initial_learning_rate, first_decay_steps, t_mul=1.2, m_mul=0.2, alpha=0.00000002
)

# Configure the LearningRateScheduler callback
learning_rate_scheduler = LearningRateScheduler(lr_warmup_decayed_fn)

resnet.compile(optimizer=Adam(learning_rate=lr_warmup_decayed_fn), loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=resnet.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),learning_rate_scheduler])

# Print the learning rate history
print(history.history["lr"])
# Out:
# Epoch 1/45
# 562/562 [==============================] - 67s 110ms/step - loss: 23.8284 - precision: 0.7253 - recall: 0.7681 - auc: 0.7601 - accuracy: 0.6985 - f_score: 0.7310 - val_loss: 18.0573 - val_precision: 0.9734 - val_recall: 0.4606 - val_auc: 0.7244 - val_accuracy: 0.4971 - val_f_score: 0.6215 - lr: 0.0183
# Epoch 2/45
# 562/562 [==============================] - 62s 110ms/step - loss: 18.6127 - precision: 0.6993 - recall: 0.7697 - auc: 0.7624 - accuracy: 0.6967 - f_score: 0.7284 - val_loss: 14.6425 - val_precision: 0.9235 - val_recall: 0.9124 - val_auc: 0.7112 - val_accuracy: 0.8513 - val_f_score: 0.9174 - lr: 0.0138
# Epoch 3/45
# 562/562 [==============================] - 61s 108ms/step - loss: 12.6088 - precision: 0.6966 - recall: 0.7711 - auc: 0.7628 - accuracy: 0.6948 - f_score: 0.7284 - val_loss: 9.2614 - val_precision: 0.9163 - val_recall: 0.9868 - val_auc: 0.6900 - val_accuracy: 0.9059 - val_f_score: 0.9492 - lr: 0.0081
# Epoch 4/45
# 562/562 [==============================] - 60s 107ms/step - loss: 6.4459 - precision: 0.7086 - recall: 0.7831 - auc: 0.7741 - accuracy: 0.7087 - f_score: 0.7408 - val_loss: 3.9502 - val_precision: 0.9663 - val_recall: 0.5602 - val_auc: 0.7222 - val_accuracy: 0.5815 - val_f_score: 0.7040 - lr: 0.0030
# Epoch 5/45
# 562/562 [==============================] - 60s 107ms/step - loss: 2.0742 - precision: 0.7120 - recall: 0.7785 - auc: 0.7772 - accuracy: 0.7101 - f_score: 0.7405 - val_loss: 0.7865 - val_precision: 0.9308 - val_recall: 0.8053 - val_auc: 0.7088 - val_accuracy: 0.7681 - val_f_score: 0.8610 - lr: 1.9936e-04
# Epoch 6/45
# 562/562 [==============================] - 60s 107ms/step - loss: 4.5320 - precision: 0.7214 - recall: 0.7843 - auc: 0.7857 - accuracy: 0.7198 - f_score: 0.7483 - val_loss: 5.6491 - val_precision: 0.9347 - val_recall: 0.7757 - val_auc: 0.7250 - val_accuracy: 0.7463 - val_f_score: 0.8469 - lr: 0.0039
# Epoch 7/45
# 562/562 [==============================] - 61s 108ms/step - loss: 5.3950 - precision: 0.7245 - recall: 0.7851 - auc: 0.7913 - accuracy: 0.7225 - f_score: 0.7501 - val_loss: 5.0488 - val_precision: 0.9728 - val_recall: 0.4499 - val_auc: 0.6907 - val_accuracy: 0.4874 - val_f_score: 0.6037 - lr: 0.0034
# Epoch 8/45
# 562/562 [==============================] - 61s 108ms/step - loss: 4.4045 - precision: 0.7273 - recall: 0.7735 - auc: 0.7913 - accuracy: 0.7209 - f_score: 0.7464 - val_loss: 4.3912 - val_precision: 0.9747 - val_recall: 0.3396 - val_auc: 0.6810 - val_accuracy: 0.3904 - val_f_score: 0.4955 - lr: 0.0025
# Epoch 9/45
# 562/562 [==============================] - 60s 107ms/step - loss: 3.0670 - precision: 0.7242 - recall: 0.7939 - auc: 0.7941 - accuracy: 0.7253 - f_score: 0.7544 - val_loss: 2.1361 - val_precision: 0.9287 - val_recall: 0.8450 - val_auc: 0.7050 - val_accuracy: 0.7997 - val_f_score: 0.8840 - lr: 0.0016
# Epoch 10/45
# 562/562 [==============================] - 60s 107ms/step - loss: 1.8672 - precision: 0.7270 - recall: 0.7845 - auc: 0.7922 - accuracy: 0.7243 - f_score: 0.7517 - val_loss: 1.4048 - val_precision: 0.9322 - val_recall: 0.7965 - val_auc: 0.6961 - val_accuracy: 0.7618 - val_f_score: 0.8569 - lr: 6.8920e-04
# Epoch 11/45
# 562/562 [==============================] - 60s 107ms/step - loss: 1.0089 - precision: 0.7237 - recall: 0.7869 - auc: 0.7963 - accuracy: 0.7225 - f_score: 0.7505 - val_loss: 0.7108 - val_precision: 0.9401 - val_recall: 0.7719 - val_auc: 0.7103 - val_accuracy: 0.7474 - val_f_score: 0.8459 - lr: 1.3221e-04
# Epoch 12/45
# 562/562 [==============================] - 61s 108ms/step - loss: 1.0091 - precision: 0.7249 - recall: 0.7960 - auc: 0.7950 - accuracy: 0.7265 - f_score: 0.7552 - val_loss: 1.5915 - val_precision: 0.9343 - val_recall: 0.8154 - val_auc: 0.7118 - val_accuracy: 0.7796 - val_f_score: 0.8687 - lr: 7.9784e-04
# Epoch 13/45
# 562/562 [==============================] - 60s 107ms/step - loss: 1.6322 - precision: 0.7345 - recall: 0.7839 - auc: 0.7991 - accuracy: 0.7301 - f_score: 0.7547 - val_loss: 1.5112 - val_precision: 0.9351 - val_recall: 0.7895 - val_auc: 0.7065 - val_accuracy: 0.7583 - val_f_score: 0.8543 - lr: 7.4857e-04
# Epoch 14/45
# 562/562 [==============================] - 60s 107ms/step - loss: 1.4905 - precision: 0.7295 - recall: 0.7875 - auc: 0.7996 - accuracy: 0.7274 - f_score: 0.7538 - val_loss: 1.5001 - val_precision: 0.9379 - val_recall: 0.7801 - val_auc: 0.7116 - val_accuracy: 0.7526 - val_f_score: 0.8482 - lr: 6.4189e-04
# Epoch 15/45
# 562/562 [==============================] - 60s 106ms/step - loss: 1.2854 - precision: 0.7332 - recall: 0.7875 - auc: 0.7996 - accuracy: 0.7303 - f_score: 0.7564 - val_loss: 1.0319 - val_precision: 0.9314 - val_recall: 0.8381 - val_auc: 0.7116 - val_accuracy: 0.7962 - val_f_score: 0.8810 - lr: 4.9536e-04
# Epoch 16/45
# 562/562 [==============================] - 60s 107ms/step - loss: 1.0662 - precision: 0.7339 - recall: 0.7843 - auc: 0.7984 - accuracy: 0.7298 - f_score: 0.7550 - val_loss: 0.9693 - val_precision: 0.9406 - val_recall: 0.7284 - val_auc: 0.7079 - val_accuracy: 0.7107 - val_f_score: 0.8199 - lr: 3.3312e-04
# Epoch 17/45
# 562/562 [==============================] - 61s 108ms/step - loss: 0.8581 - precision: 0.7283 - recall: 0.7898 - auc: 0.8013 - accuracy: 0.7272 - f_score: 0.7552 - val_loss: 0.7428 - val_precision: 0.9390 - val_recall: 0.7669 - val_auc: 0.7130 - val_accuracy: 0.7423 - val_f_score: 0.8408 - lr: 1.8190e-04
# Epoch 18/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.7056 - precision: 0.7323 - recall: 0.7830 - auc: 0.7981 - accuracy: 0.7280 - f_score: 0.7534 - val_loss: 0.6214 - val_precision: 0.9376 - val_recall: 0.7675 - val_auc: 0.7072 - val_accuracy: 0.7417 - val_f_score: 0.8401 - lr: 6.6607e-05
# Epoch 19/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.6036 - precision: 0.7275 - recall: 0.7896 - auc: 0.7979 - accuracy: 0.7265 - f_score: 0.7547 - val_loss: 0.5433 - val_precision: 0.9378 - val_recall: 0.7795 - val_auc: 0.7070 - val_accuracy: 0.7520 - val_f_score: 0.8501 - lr: 6.2298e-06
# Epoch 20/45
# 562/562 [==============================] - 61s 108ms/step - loss: 0.7057 - precision: 0.7305 - recall: 0.7928 - auc: 0.8000 - accuracy: 0.7299 - f_score: 0.7572 - val_loss: 0.7346 - val_precision: 0.9340 - val_recall: 0.8028 - val_auc: 0.7092 - val_accuracy: 0.7687 - val_f_score: 0.8617 - lr: 1.5851e-04
# Epoch 21/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.7680 - precision: 0.7288 - recall: 0.7894 - auc: 0.8006 - accuracy: 0.7275 - f_score: 0.7552 - val_loss: 0.6728 - val_precision: 0.9336 - val_recall: 0.8330 - val_auc: 0.7150 - val_accuracy: 0.7939 - val_f_score: 0.8772 - lr: 1.4887e-04
# Epoch 22/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.7468 - precision: 0.7284 - recall: 0.7873 - auc: 0.7987 - accuracy: 0.7264 - f_score: 0.7538 - val_loss: 0.7033 - val_precision: 0.9383 - val_recall: 0.7952 - val_auc: 0.7170 - val_accuracy: 0.7658 - val_f_score: 0.8595 - lr: 1.3131e-04
# Epoch 23/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.7145 - precision: 0.7330 - recall: 0.7875 - auc: 0.8001 - accuracy: 0.7302 - f_score: 0.7568 - val_loss: 0.6839 - val_precision: 0.9415 - val_recall: 0.7511 - val_auc: 0.7094 - val_accuracy: 0.7308 - val_f_score: 0.8326 - lr: 1.0786e-04
# Epoch 24/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.6792 - precision: 0.7340 - recall: 0.7829 - auc: 0.8001 - accuracy: 0.7294 - f_score: 0.7556 - val_loss: 0.6435 - val_precision: 0.9403 - val_recall: 0.7543 - val_auc: 0.7097 - val_accuracy: 0.7325 - val_f_score: 0.8329 - lr: 8.1212e-05
# Epoch 25/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.6438 - precision: 0.7321 - recall: 0.7828 - auc: 0.7996 - accuracy: 0.7278 - f_score: 0.7529 - val_loss: 0.6127 - val_precision: 0.9397 - val_recall: 0.7555 - val_auc: 0.7089 - val_accuracy: 0.7331 - val_f_score: 0.8366 - lr: 5.4423e-05
# Epoch 26/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.6132 - precision: 0.7328 - recall: 0.7835 - auc: 0.7993 - accuracy: 0.7287 - f_score: 0.7543 - val_loss: 0.5637 - val_precision: 0.9373 - val_recall: 0.7813 - val_auc: 0.7102 - val_accuracy: 0.7532 - val_f_score: 0.8498 - lr: 3.0572e-05
# Epoch 27/45
# 562/562 [==============================] - 60s 107ms/step - loss: 0.5881 - precision: 0.7313 - recall: 0.7842 - auc: 0.7993 - accuracy: 0.7277 - f_score: 0.7537 - val_loss: 0.5559 - val_precision: 0.9398 - val_recall: 0.7669 - val_auc: 0.7109 - val_accuracy: 0.7428 - val_f_score: 0.8394 - lr: 1.2399e-05
# Epoch 28/45
# 562/562 [==============================] - 61s 108ms/step - loss: 0.5699 - precision: 0.7348 - recall: 0.7879 - auc: 0.8023 - accuracy: 0.7317 - f_score: 0.7572 - val_loss: 0.5395 - val_precision: 0.9394 - val_recall: 0.7713 - val_auc: 0.7111 - val_accuracy: 0.7463 - val_f_score: 0.8444 - lr: 1.9923e-06
# [0.018323412, 0.013846176, 0.008074781, 0.0029511806, 0.00019936363, 0.0038960932, 0.0033729065, 0.0025260628, 0.0015552015, 0.0006891997, 0.00013221495, 0.0007978394, 0.00074857153, 0.00064188626, 0.00049535715, 0.00033312067, 0.00018190074, 6.660664e-05, 6.229753e-06, 0.00015851014, 0.00014886667, 0.00013131196, 0.00010786255, 8.1212434e-05, 5.4423017e-05, 3.057197e-05, 1.2399153e-05, 1.99233e-06]

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
