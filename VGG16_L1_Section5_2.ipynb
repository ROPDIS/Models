# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/VGG16_L1_Section5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

VGG = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(60,80,3),
    pooling=None)

for layer in pretrained_model.layers:
    layer.trainable = False

VGG.add(pretrained_model)

VGG.add(tf.keras.layers.Flatten())
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2, activity_regularizer=L1(0.01))) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2, activity_regularizer=L1(0.01))) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(1, activation='sigmoid'))

VGG.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 2, 512)         14714688
#
#  flatten (Flatten)           (None, 1024)              0
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 15,246,145
# Trainable params: 528,385
# Non-trainable params: 14,717,760
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

VGG.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history = VGG.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=15,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3054s 5s/step - loss: 16.3641 - precision: 0.6938 - recall: 0.7876 - auc: 0.7550 - accuracy: 0.6974 - f_score: 0.7327 - val_loss: 14.3428 - val_precision: 1.0000 - val_recall: 0.0208 - val_auc: 0.8416 - val_accuracy: 0.1079 - val_f_score: 0.0398 - lr: 0.0200
# Epoch 2/45
# 562/562 [==============================] - 105s 188ms/step - loss: 13.7538 - precision: 0.6925 - recall: 0.7878 - auc: 0.7551 - accuracy: 0.6963 - f_score: 0.7329 - val_loss: 14.1749 - val_precision: 0.9774 - val_recall: 0.4089 - val_auc: 0.8309 - val_accuracy: 0.4529 - val_f_score: 0.5720 - lr: 0.0200
# Epoch 3/45
# 562/562 [==============================] - 97s 173ms/step - loss: 13.7714 - precision: 0.6958 - recall: 0.7927 - auc: 0.7623 - accuracy: 0.7007 - f_score: 0.7379 - val_loss: 13.6647 - val_precision: 0.9580 - val_recall: 0.7618 - val_auc: 0.7697 - val_accuracy: 0.7526 - val_f_score: 0.8471 - lr: 0.0200
# Epoch 4/45
# 562/562 [==============================] - 95s 168ms/step - loss: 13.7762 - precision: 0.6878 - recall: 0.7980 - auc: 0.7563 - accuracy: 0.6950 - f_score: 0.7348 - val_loss: 14.1399 - val_precision: 0.9688 - val_recall: 0.7032 - val_auc: 0.7917 - val_accuracy: 0.7090 - val_f_score: 0.8117 - lr: 0.0200
# Epoch 5/45
# 562/562 [==============================] - 94s 168ms/step - loss: 13.7733 - precision: 0.6984 - recall: 0.8027 - auc: 0.7661 - accuracy: 0.7060 - f_score: 0.7427 - val_loss: 13.8693 - val_precision: 0.9796 - val_recall: 0.5142 - val_auc: 0.7540 - val_accuracy: 0.5476 - val_f_score: 0.6714 - lr: 0.0200
# Epoch 6/45
# 562/562 [==============================] - 94s 168ms/step - loss: 13.7809 - precision: 0.7034 - recall: 0.7982 - auc: 0.7687 - accuracy: 0.7090 - f_score: 0.7445 - val_loss: 13.8345 - val_precision: 0.9953 - val_recall: 0.2647 - val_auc: 0.7561 - val_accuracy: 0.3289 - val_f_score: 0.4123 - lr: 0.0200
# Epoch 7/45
# 562/562 [==============================] - 95s 168ms/step - loss: 13.7854 - precision: 0.6998 - recall: 0.7928 - auc: 0.7642 - accuracy: 0.7042 - f_score: 0.7393 - val_loss: 14.3231 - val_precision: 0.9672 - val_recall: 0.6679 - val_auc: 0.7685 - val_accuracy: 0.6768 - val_f_score: 0.7842 - lr: 0.0200
# Epoch 8/45
# 562/562 [==============================] - 94s 167ms/step - loss: 2.1017 - precision: 0.7186 - recall: 0.8122 - auc: 0.7909 - accuracy: 0.7266 - f_score: 0.7589 - val_loss: 2.0085 - val_precision: 0.9556 - val_recall: 0.5967 - val_auc: 0.7067 - val_accuracy: 0.6073 - val_f_score: 0.7304 - lr: 0.0020
# Epoch 9/45
# 562/562 [==============================] - 94s 167ms/step - loss: 1.8747 - precision: 0.7163 - recall: 0.8072 - auc: 0.7876 - accuracy: 0.7231 - f_score: 0.7557 - val_loss: 2.0898 - val_precision: 0.9718 - val_recall: 0.5211 - val_auc: 0.7452 - val_accuracy: 0.5499 - val_f_score: 0.6720 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 94s 167ms/step - loss: 1.8692 - precision: 0.7134 - recall: 0.8102 - auc: 0.7900 - accuracy: 0.7215 - f_score: 0.7549 - val_loss: 2.1570 - val_precision: 0.9550 - val_recall: 0.5350 - val_auc: 0.6606 - val_accuracy: 0.5534 - val_f_score: 0.6790 - lr: 0.0020
# Epoch 11/45
# 562/562 [==============================] - 94s 167ms/step - loss: 1.8669 - precision: 0.7186 - recall: 0.8092 - auc: 0.7898 - accuracy: 0.7257 - f_score: 0.7583 - val_loss: 1.9730 - val_precision: 0.9677 - val_recall: 0.6043 - val_auc: 0.7394 - val_accuracy: 0.6211 - val_f_score: 0.7411 - lr: 0.0020
# Epoch 12/45
# 562/562 [==============================] - 95s 168ms/step - loss: 0.7232 - precision: 0.7234 - recall: 0.8103 - auc: 0.7946 - accuracy: 0.7301 - f_score: 0.7613 - val_loss: 0.8936 - val_precision: 0.9632 - val_recall: 0.5110 - val_auc: 0.7010 - val_accuracy: 0.5367 - val_f_score: 0.6615 - lr: 2.0000e-04
# Epoch 13/45
# 562/562 [==============================] - 92s 164ms/step - loss: 0.6991 - precision: 0.7245 - recall: 0.8163 - auc: 0.7981 - accuracy: 0.7329 - f_score: 0.7643 - val_loss: 0.8726 - val_precision: 0.9592 - val_recall: 0.5337 - val_auc: 0.7017 - val_accuracy: 0.5545 - val_f_score: 0.6827 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 92s 164ms/step - loss: 0.7019 - precision: 0.7239 - recall: 0.8127 - auc: 0.7948 - accuracy: 0.7313 - f_score: 0.7617 - val_loss: 0.8827 - val_precision: 0.9635 - val_recall: 0.5154 - val_auc: 0.7081 - val_accuracy: 0.5408 - val_f_score: 0.6681 - lr: 2.0000e-04
# Epoch 15/45
# 562/562 [==============================] - 93s 165ms/step - loss: 0.6991 - precision: 0.7259 - recall: 0.8068 - auc: 0.7964 - accuracy: 0.7310 - f_score: 0.7610 - val_loss: 0.8528 - val_precision: 0.9563 - val_recall: 0.5514 - val_auc: 0.6992 - val_accuracy: 0.5683 - val_f_score: 0.6960 - lr: 2.0000e-04
# Epoch 16/45
# 562/562 [==============================] - 92s 164ms/step - loss: 0.5831 - precision: 0.7230 - recall: 0.8171 - auc: 0.7981 - accuracy: 0.7320 - f_score: 0.7635 - val_loss: 0.7496 - val_precision: 0.9566 - val_recall: 0.5413 - val_auc: 0.6971 - val_accuracy: 0.5597 - val_f_score: 0.6876 - lr: 2.0000e-05
# Epoch 17/45
# 562/562 [==============================] - 92s 164ms/step - loss: 0.5836 - precision: 0.7226 - recall: 0.8167 - auc: 0.7952 - accuracy: 0.7316 - f_score: 0.7634 - val_loss: 0.7496 - val_precision: 0.9584 - val_recall: 0.5369 - val_auc: 0.7009 - val_accuracy: 0.5568 - val_f_score: 0.6839 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 93s 165ms/step - loss: 0.5807 - precision: 0.7223 - recall: 0.8144 - auc: 0.7981 - accuracy: 0.7305 - f_score: 0.7619 - val_loss: 0.7465 - val_precision: 0.9567 - val_recall: 0.5432 - val_auc: 0.7016 - val_accuracy: 0.5614 - val_f_score: 0.6876 - lr: 2.0000e-05

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = VGG.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 55/55 [==============================] - 7s 116ms/step
# AUC: 0.5262068825334878
