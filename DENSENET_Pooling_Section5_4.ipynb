# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_Pooling_Section5_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.GlobalMaxPooling2D())
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  global_max_pooling2d (Globa  (None, 1920)             0
#  lMaxPooling2D)
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  dense (Dense)               (None, 512)               983552
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 19,315,777
# Trainable params: 988,929
# Non-trainable params: 18,326,848
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.002)

dense.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3491s 6s/step - loss: 13.3170 - precision: 0.7195 - recall: 0.7866 - auc: 0.7808 - accuracy: 0.7190 - f_score: 0.7487 - val_loss: 3.3734 - val_precision: 0.9442 - val_recall: 0.6402 - val_auc: 0.6722 - val_accuracy: 0.6378 - val_f_score: 0.7584 - lr: 0.0020
# Epoch 2/45
# 562/562 [==============================] - 104s 185ms/step - loss: 2.9590 - precision: 0.7381 - recall: 0.8034 - auc: 0.8074 - accuracy: 0.7397 - f_score: 0.7664 - val_loss: 2.7821 - val_precision: 0.9385 - val_recall: 0.8752 - val_auc: 0.7402 - val_accuracy: 0.8341 - val_f_score: 0.9057 - lr: 0.0020
# Epoch 3/45
# 562/562 [==============================] - 106s 188ms/step - loss: 2.8679 - precision: 0.7435 - recall: 0.8039 - auc: 0.8084 - accuracy: 0.7442 - f_score: 0.7701 - val_loss: 2.8325 - val_precision: 0.9341 - val_recall: 0.8399 - val_auc: 0.7076 - val_accuracy: 0.8002 - val_f_score: 0.8827 - lr: 0.0020
# Epoch 4/45
# 562/562 [==============================] - 109s 194ms/step - loss: 2.8901 - precision: 0.7403 - recall: 0.7940 - auc: 0.8073 - accuracy: 0.7382 - f_score: 0.7630 - val_loss: 2.7372 - val_precision: 0.9324 - val_recall: 0.9389 - val_auc: 0.7701 - val_accuracy: 0.8823 - val_f_score: 0.9353 - lr: 0.0020
# Epoch 5/45
# 562/562 [==============================] - 103s 183ms/step - loss: 2.8989 - precision: 0.7462 - recall: 0.7970 - auc: 0.8100 - accuracy: 0.7439 - f_score: 0.7676 - val_loss: 2.9121 - val_precision: 0.9550 - val_recall: 0.7486 - val_auc: 0.7454 - val_accuracy: 0.7388 - val_f_score: 0.8373 - lr: 0.0020
# Epoch 6/45
# 562/562 [==============================] - 106s 189ms/step - loss: 2.9090 - precision: 0.7399 - recall: 0.7933 - auc: 0.8073 - accuracy: 0.7376 - f_score: 0.7625 - val_loss: 2.8257 - val_precision: 0.9374 - val_recall: 0.8778 - val_auc: 0.7520 - val_accuracy: 0.8352 - val_f_score: 0.9055 - lr: 0.0020
# Epoch 7/45
# 562/562 [==============================] - 106s 189ms/step - loss: 2.9117 - precision: 0.7470 - recall: 0.7946 - auc: 0.8091 - accuracy: 0.7436 - f_score: 0.7668 - val_loss: 2.7285 - val_precision: 0.9203 - val_recall: 0.9679 - val_auc: 0.7444 - val_accuracy: 0.8944 - val_f_score: 0.9434 - lr: 0.0020
# Epoch 8/45
# 562/562 [==============================] - 104s 184ms/step - loss: 2.9169 - precision: 0.7449 - recall: 0.7922 - auc: 0.8091 - accuracy: 0.7411 - f_score: 0.7651 - val_loss: 2.7814 - val_precision: 0.9326 - val_recall: 0.9162 - val_auc: 0.7654 - val_accuracy: 0.8634 - val_f_score: 0.9234 - lr: 0.0020
# Epoch 9/45
# 562/562 [==============================] - 104s 185ms/step - loss: 2.9231 - precision: 0.7435 - recall: 0.7887 - auc: 0.8051 - accuracy: 0.7388 - f_score: 0.7619 - val_loss: 2.8567 - val_precision: 0.9578 - val_recall: 0.8154 - val_auc: 0.8255 - val_accuracy: 0.7991 - val_f_score: 0.8785 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 105s 187ms/step - loss: 2.9171 - precision: 0.7466 - recall: 0.7968 - auc: 0.8118 - accuracy: 0.7441 - f_score: 0.7681 - val_loss: 2.9872 - val_precision: 0.9686 - val_recall: 0.6793 - val_auc: 0.7994 - val_accuracy: 0.6877 - val_f_score: 0.7954 - lr: 0.0020
# Epoch 11/45
# 562/562 [==============================] - 104s 185ms/step - loss: 2.9241 - precision: 0.7410 - recall: 0.7847 - auc: 0.8061 - accuracy: 0.7354 - f_score: 0.7596 - val_loss: 2.7725 - val_precision: 0.9346 - val_recall: 0.9181 - val_auc: 0.7620 - val_accuracy: 0.8668 - val_f_score: 0.9251 - lr: 0.0020
# Epoch 12/45
# 562/562 [==============================] - 102s 181ms/step - loss: 0.8445 - precision: 0.7511 - recall: 0.8079 - auc: 0.8215 - accuracy: 0.7515 - f_score: 0.7750 - val_loss: 0.7580 - val_precision: 0.9449 - val_recall: 0.8431 - val_auc: 0.7539 - val_accuracy: 0.8123 - val_f_score: 0.8893 - lr: 2.0000e-04
# Epoch 13/45
# 562/562 [==============================] - 109s 195ms/step - loss: 0.7981 - precision: 0.7565 - recall: 0.8069 - auc: 0.8264 - accuracy: 0.7553 - f_score: 0.7776 - val_loss: 0.7578 - val_precision: 0.9456 - val_recall: 0.8318 - val_auc: 0.7658 - val_accuracy: 0.8031 - val_f_score: 0.8830 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 103s 183ms/step - loss: 0.7972 - precision: 0.7615 - recall: 0.8032 - auc: 0.8261 - accuracy: 0.7577 - f_score: 0.7796 - val_loss: 0.7431 - val_precision: 0.9464 - val_recall: 0.8450 - val_auc: 0.7573 - val_accuracy: 0.8152 - val_f_score: 0.8909 - lr: 2.0000e-04
# Epoch 15/45
# 562/562 [==============================] - 102s 181ms/step - loss: 0.7969 - precision: 0.7555 - recall: 0.8123 - auc: 0.8261 - accuracy: 0.7565 - f_score: 0.7794 - val_loss: 0.7315 - val_precision: 0.9444 - val_recall: 0.8570 - val_auc: 0.7691 - val_accuracy: 0.8238 - val_f_score: 0.8977 - lr: 2.0000e-04
# Epoch 16/45
# 562/562 [==============================] - 103s 183ms/step - loss: 0.5847 - precision: 0.7562 - recall: 0.8065 - auc: 0.8245 - accuracy: 0.7549 - f_score: 0.7781 - val_loss: 0.5100 - val_precision: 0.9432 - val_recall: 0.8683 - val_auc: 0.7696 - val_accuracy: 0.8324 - val_f_score: 0.9030 - lr: 2.0000e-05
# Epoch 17/45
# 562/562 [==============================] - 102s 182ms/step - loss: 0.5809 - precision: 0.7538 - recall: 0.8079 - auc: 0.8233 - accuracy: 0.7536 - f_score: 0.7773 - val_loss: 0.5174 - val_precision: 0.9446 - val_recall: 0.8601 - val_auc: 0.7682 - val_accuracy: 0.8266 - val_f_score: 0.8980 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 101s 180ms/step - loss: 0.5835 - precision: 0.7523 - recall: 0.8011 - auc: 0.8217 - accuracy: 0.7500 - f_score: 0.7730 - val_loss: 0.5130 - val_precision: 0.9435 - val_recall: 0.8633 - val_auc: 0.7656 - val_accuracy: 0.8284 - val_f_score: 0.8999 - lr: 2.0000e-05
# Epoch 19/45
# 562/562 [==============================] - 108s 192ms/step - loss: 0.5827 - precision: 0.7512 - recall: 0.8019 - auc: 0.8225 - accuracy: 0.7494 - f_score: 0.7719 - val_loss: 0.5207 - val_precision: 0.9452 - val_recall: 0.8589 - val_auc: 0.7707 - val_accuracy: 0.8261 - val_f_score: 0.8984 - lr: 2.0000e-05
# Epoch 20/45
# 562/562 [==============================] - 106s 188ms/step - loss: 0.5576 - precision: 0.7594 - recall: 0.8098 - auc: 0.8251 - accuracy: 0.7586 - f_score: 0.7813 - val_loss: 0.4924 - val_precision: 0.9435 - val_recall: 0.8633 - val_auc: 0.7661 - val_accuracy: 0.8284 - val_f_score: 0.9005 - lr: 2.0000e-06
# Epoch 21/45
# 562/562 [==============================] - 100s 178ms/step - loss: 0.5615 - precision: 0.7542 - recall: 0.8093 - auc: 0.8221 - accuracy: 0.7544 - f_score: 0.7778 - val_loss: 0.4996 - val_precision: 0.9445 - val_recall: 0.8576 - val_auc: 0.7695 - val_accuracy: 0.8243 - val_f_score: 0.8985 - lr: 2.0000e-06
# Epoch 22/45
# 562/562 [==============================] - 101s 180ms/step - loss: 0.5533 - precision: 0.7607 - recall: 0.8083 - auc: 0.8303 - accuracy: 0.7590 - f_score: 0.7810 - val_loss: 0.4957 - val_precision: 0.9453 - val_recall: 0.8607 - val_auc: 0.7720 - val_accuracy: 0.8278 - val_f_score: 0.8995 - lr: 2.0000e-06
# Epoch 23/45
# 562/562 [==============================] - 101s 179ms/step - loss: 0.5607 - precision: 0.7565 - recall: 0.7992 - auc: 0.8231 - accuracy: 0.7525 - f_score: 0.7742 - val_loss: 0.4929 - val_precision: 0.9435 - val_recall: 0.8633 - val_auc: 0.7683 - val_accuracy: 0.8284 - val_f_score: 0.8993 - lr: 2.0000e-06
# Epoch 24/45
# 562/562 [==============================] - 101s 179ms/step - loss: 0.5586 - precision: 0.7573 - recall: 0.8119 - auc: 0.8240 - accuracy: 0.7578 - f_score: 0.7796 - val_loss: 0.4922 - val_precision: 0.9435 - val_recall: 0.8626 - val_auc: 0.7660 - val_accuracy: 0.8278 - val_f_score: 0.9001 - lr: 2.0000e-07
# Epoch 25/45
# 562/562 [==============================] - 103s 184ms/step - loss: 0.5524 - precision: 0.7579 - recall: 0.8061 - auc: 0.8275 - accuracy: 0.7560 - f_score: 0.7783 - val_loss: 0.4945 - val_precision: 0.9441 - val_recall: 0.8614 - val_auc: 0.7696 - val_accuracy: 0.8272 - val_f_score: 0.8992 - lr: 2.0000e-07
# Epoch 26/45
# 562/562 [==============================] - 107s 191ms/step - loss: 0.5521 - precision: 0.7592 - recall: 0.8165 - auc: 0.8282 - accuracy: 0.7609 - f_score: 0.7841 - val_loss: 0.4917 - val_precision: 0.9434 - val_recall: 0.8614 - val_auc: 0.7671 - val_accuracy: 0.8266 - val_f_score: 0.8992 - lr: 2.0000e-07
# Epoch 27/45
# 562/562 [==============================] - 101s 180ms/step - loss: 0.5586 - precision: 0.7578 - recall: 0.8041 - auc: 0.8230 - accuracy: 0.7553 - f_score: 0.7784 - val_loss: 0.4937 - val_precision: 0.9441 - val_recall: 0.8620 - val_auc: 0.7713 - val_accuracy: 0.8278 - val_f_score: 0.9002 - lr: 2.0000e-07
# Epoch 28/45
# 562/562 [==============================] - 100s 177ms/step - loss: 0.5522 - precision: 0.7597 - recall: 0.8077 - auc: 0.8291 - accuracy: 0.7580 - f_score: 0.7801 - val_loss: 0.4977 - val_precision: 0.9445 - val_recall: 0.8582 - val_auc: 0.7670 - val_accuracy: 0.8249 - val_f_score: 0.8972 - lr: 2.0000e-08
# Epoch 29/45
# 562/562 [==============================] - 100s 178ms/step - loss: 0.5507 - precision: 0.7595 - recall: 0.8095 - auc: 0.8289 - accuracy: 0.7585 - f_score: 0.7814 - val_loss: 0.4935 - val_precision: 0.9459 - val_recall: 0.8601 - val_auc: 0.7741 - val_accuracy: 0.8278 - val_f_score: 0.8990 - lr: 2.0000e-08
# Epoch 30/45
# 562/562 [==============================] - 99s 176ms/step - loss: 0.5535 - precision: 0.7598 - recall: 0.8096 - auc: 0.8279 - accuracy: 0.7588 - f_score: 0.7808 - val_loss: 0.4926 - val_precision: 0.9441 - val_recall: 0.8614 - val_auc: 0.7704 - val_accuracy: 0.8272 - val_f_score: 0.8993 - lr: 2.0000e-08
# Epoch 31/45
# 562/562 [==============================] - 100s 178ms/step - loss: 0.5510 - precision: 0.7628 - recall: 0.8165 - auc: 0.8306 - accuracy: 0.7636 - f_score: 0.7856 - val_loss: 0.4920 - val_precision: 0.9428 - val_recall: 0.8626 - val_auc: 0.7677 - val_accuracy: 0.8272 - val_f_score: 0.8989 - lr: 2.0000e-08
# Epoch 32/45
# 562/562 [==============================] - 100s 178ms/step - loss: 0.5573 - precision: 0.7556 - recall: 0.8020 - auc: 0.8223 - accuracy: 0.7528 - f_score: 0.7750 - val_loss: 0.4934 - val_precision: 0.9448 - val_recall: 0.8626 - val_auc: 0.7689 - val_accuracy: 0.8289 - val_f_score: 0.9002 - lr: 2.0000e-09

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
