# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/RESNET_BatchSize_32_Section5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
resnet = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.ResNet50V2(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

resnet.add(pretrained_model)

resnet.add(tf.keras.layers.GlobalMaxPooling2D())  # Use GlobalMaxPooling2D
resnet.add(BatchNormalization())  # Add BatchNormalization layer
resnet.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
resnet.add(tf.keras.layers.Dense(512, activation='relu'))
resnet.add(BatchNormalization())  # Add BatchNormalization layer
resnet.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
resnet.add(tf.keras.layers.Dense(1, activation='sigmoid'))

resnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 2, 3, 2048)        23564800
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
#  batch_normalization (BatchN  (None, 2048)             8192
#  ormalization)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 24,624,641
# Trainable params: 1,054,721
# Non-trainable params: 23,569,920
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

resnet.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=resnet.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3229s 6s/step - loss: 0.5427 - precision: 0.7738 - recall: 0.7909 - auc: 0.8327 - accuracy: 0.7620 - f_score: 0.7787 - val_loss: 0.4749 - val_precision: 0.9694 - val_recall: 0.7795 - val_auc: 0.8282 - val_accuracy: 0.7767 - val_f_score: 0.8622 - lr: 0.0200
# Epoch 2/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4590 - precision: 0.7929 - recall: 0.8267 - auc: 0.8643 - accuracy: 0.7896 - f_score: 0.8074 - val_loss: 0.5439 - val_precision: 0.9762 - val_recall: 0.7486 - val_auc: 0.8401 - val_accuracy: 0.7543 - val_f_score: 0.8450 - lr: 0.0200
# Epoch 3/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4474 - precision: 0.7994 - recall: 0.8280 - auc: 0.8715 - accuracy: 0.7948 - f_score: 0.8104 - val_loss: 0.4514 - val_precision: 0.9684 - val_recall: 0.7921 - val_auc: 0.8524 - val_accuracy: 0.7870 - val_f_score: 0.8696 - lr: 0.0200
# Epoch 4/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.4423 - precision: 0.8052 - recall: 0.8298 - auc: 0.8752 - accuracy: 0.7996 - f_score: 0.8146 - val_loss: 0.3340 - val_precision: 0.9502 - val_recall: 0.9017 - val_auc: 0.8535 - val_accuracy: 0.8674 - val_f_score: 0.9243 - lr: 0.0200
# Epoch 5/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4385 - precision: 0.8065 - recall: 0.8316 - auc: 0.8774 - accuracy: 0.8012 - f_score: 0.8163 - val_loss: 0.4797 - val_precision: 0.9700 - val_recall: 0.7750 - val_auc: 0.8524 - val_accuracy: 0.7732 - val_f_score: 0.8611 - lr: 0.0200
# Epoch 6/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4429 - precision: 0.8028 - recall: 0.8244 - auc: 0.8752 - accuracy: 0.7957 - f_score: 0.8107 - val_loss: 0.7313 - val_precision: 0.9834 - val_recall: 0.5961 - val_auc: 0.8508 - val_accuracy: 0.6228 - val_f_score: 0.7362 - lr: 0.0200
# Epoch 7/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4355 - precision: 0.8027 - recall: 0.8343 - auc: 0.8792 - accuracy: 0.7996 - f_score: 0.8147 - val_loss: 0.9118 - val_precision: 0.9875 - val_recall: 0.4972 - val_auc: 0.8462 - val_accuracy: 0.5362 - val_f_score: 0.6573 - lr: 0.0200
# Epoch 8/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4350 - precision: 0.8076 - recall: 0.8345 - auc: 0.8798 - accuracy: 0.8031 - f_score: 0.8185 - val_loss: 0.5638 - val_precision: 0.9723 - val_recall: 0.7089 - val_auc: 0.8383 - val_accuracy: 0.7164 - val_f_score: 0.8160 - lr: 0.0200
# Epoch 9/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4164 - precision: 0.8160 - recall: 0.8398 - auc: 0.8897 - accuracy: 0.8111 - f_score: 0.8256 - val_loss: 0.6730 - val_precision: 0.9833 - val_recall: 0.6295 - val_auc: 0.8670 - val_accuracy: 0.6527 - val_f_score: 0.7635 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4092 - precision: 0.8193 - recall: 0.8416 - auc: 0.8938 - accuracy: 0.8141 - f_score: 0.8281 - val_loss: 0.6882 - val_precision: 0.9844 - val_recall: 0.6358 - val_auc: 0.8648 - val_accuracy: 0.6590 - val_f_score: 0.7685 - lr: 0.0020
# Epoch 11/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4053 - precision: 0.8185 - recall: 0.8486 - auc: 0.8963 - accuracy: 0.8165 - f_score: 0.8308 - val_loss: 0.7554 - val_precision: 0.9860 - val_recall: 0.5759 - val_auc: 0.8613 - val_accuracy: 0.6062 - val_f_score: 0.7205 - lr: 0.0020
# Epoch 12/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4022 - precision: 0.8236 - recall: 0.8489 - auc: 0.8977 - accuracy: 0.8201 - f_score: 0.8335 - val_loss: 0.6529 - val_precision: 0.9848 - val_recall: 0.6541 - val_auc: 0.8738 - val_accuracy: 0.6757 - val_f_score: 0.7806 - lr: 0.0020
# Epoch 13/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.4002 - precision: 0.8195 - recall: 0.8543 - auc: 0.8982 - accuracy: 0.8196 - f_score: 0.8340 - val_loss: 0.6849 - val_precision: 0.9844 - val_recall: 0.6352 - val_auc: 0.8698 - val_accuracy: 0.6584 - val_f_score: 0.7686 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4013 - precision: 0.8187 - recall: 0.8510 - auc: 0.8977 - accuracy: 0.8176 - f_score: 0.8327 - val_loss: 0.6935 - val_precision: 0.9843 - val_recall: 0.6307 - val_auc: 0.8688 - val_accuracy: 0.6544 - val_f_score: 0.7633 - lr: 2.0000e-04
# Epoch 15/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.3985 - precision: 0.8214 - recall: 0.8516 - auc: 0.8993 - accuracy: 0.8198 - f_score: 0.8344 - val_loss: 0.6857 - val_precision: 0.9845 - val_recall: 0.6383 - val_auc: 0.8683 - val_accuracy: 0.6613 - val_f_score: 0.7715 - lr: 2.0000e-04
# Epoch 16/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.4019 - precision: 0.8173 - recall: 0.8551 - auc: 0.8976 - accuracy: 0.8184 - f_score: 0.8332 - val_loss: 0.6898 - val_precision: 0.9853 - val_recall: 0.6320 - val_auc: 0.8697 - val_accuracy: 0.6561 - val_f_score: 0.7654 - lr: 2.0000e-04
# Epoch 17/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4042 - precision: 0.8225 - recall: 0.8453 - auc: 0.8967 - accuracy: 0.8178 - f_score: 0.8313 - val_loss: 0.6810 - val_precision: 0.9844 - val_recall: 0.6377 - val_auc: 0.8694 - val_accuracy: 0.6607 - val_f_score: 0.7716 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4025 - precision: 0.8182 - recall: 0.8473 - auc: 0.8972 - accuracy: 0.8157 - f_score: 0.8297 - val_loss: 0.6972 - val_precision: 0.9843 - val_recall: 0.6333 - val_auc: 0.8678 - val_accuracy: 0.6567 - val_f_score: 0.7676 - lr: 2.0000e-05
# Epoch 19/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4045 - precision: 0.8191 - recall: 0.8462 - auc: 0.8960 - accuracy: 0.8159 - f_score: 0.8302 - val_loss: 0.6895 - val_precision: 0.9853 - val_recall: 0.6320 - val_auc: 0.8693 - val_accuracy: 0.6561 - val_f_score: 0.7663 - lr: 2.0000e-05
# Epoch 20/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4014 - precision: 0.8183 - recall: 0.8500 - auc: 0.8979 - accuracy: 0.8169 - f_score: 0.8313 - val_loss: 0.6718 - val_precision: 0.9846 - val_recall: 0.6440 - val_auc: 0.8683 - val_accuracy: 0.6665 - val_f_score: 0.7739 - lr: 2.0000e-05
# Epoch 21/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.3960 - precision: 0.8251 - recall: 0.8541 - auc: 0.9003 - accuracy: 0.8233 - f_score: 0.8373 - val_loss: 0.6750 - val_precision: 0.9845 - val_recall: 0.6415 - val_auc: 0.8679 - val_accuracy: 0.6642 - val_f_score: 0.7730 - lr: 2.0000e-06
# Epoch 22/45
# 562/562 [==============================] - 66s 117ms/step - loss: 0.3989 - precision: 0.8241 - recall: 0.8537 - auc: 0.8996 - accuracy: 0.8224 - f_score: 0.8363 - val_loss: 0.6871 - val_precision: 0.9844 - val_recall: 0.6371 - val_auc: 0.8689 - val_accuracy: 0.6602 - val_f_score: 0.7700 - lr: 2.0000e-06
# Epoch 23/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.3988 - precision: 0.8231 - recall: 0.8555 - auc: 0.8995 - accuracy: 0.8225 - f_score: 0.8366 - val_loss: 0.6789 - val_precision: 0.9845 - val_recall: 0.6389 - val_auc: 0.8689 - val_accuracy: 0.6619 - val_f_score: 0.7705 - lr: 2.0000e-06
# Epoch 24/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.3990 - precision: 0.8212 - recall: 0.8472 - auc: 0.8986 - accuracy: 0.8178 - f_score: 0.8320 - val_loss: 0.6837 - val_precision: 0.9854 - val_recall: 0.6364 - val_auc: 0.8688 - val_accuracy: 0.6602 - val_f_score: 0.7679 - lr: 2.0000e-06
# Epoch 25/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4003 - precision: 0.8213 - recall: 0.8567 - auc: 0.8983 - accuracy: 0.8218 - f_score: 0.8363 - val_loss: 0.6797 - val_precision: 0.9845 - val_recall: 0.6421 - val_auc: 0.8664 - val_accuracy: 0.6648 - val_f_score: 0.7728 - lr: 2.0000e-07
# Epoch 26/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.3995 - precision: 0.8248 - recall: 0.8515 - auc: 0.8994 - accuracy: 0.8220 - f_score: 0.8356 - val_loss: 0.7053 - val_precision: 0.9861 - val_recall: 0.6257 - val_auc: 0.8678 - val_accuracy: 0.6510 - val_f_score: 0.7586 - lr: 2.0000e-07
# Epoch 27/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4043 - precision: 0.8174 - recall: 0.8516 - auc: 0.8964 - accuracy: 0.8170 - f_score: 0.8317 - val_loss: 0.6890 - val_precision: 0.9843 - val_recall: 0.6326 - val_auc: 0.8675 - val_accuracy: 0.6561 - val_f_score: 0.7677 - lr: 2.0000e-07
# Epoch 28/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.3983 - precision: 0.8249 - recall: 0.8517 - auc: 0.8995 - accuracy: 0.8221 - f_score: 0.8358 - val_loss: 0.6719 - val_precision: 0.9846 - val_recall: 0.6440 - val_auc: 0.8679 - val_accuracy: 0.6665 - val_f_score: 0.7750 - lr: 2.0000e-07
# Epoch 29/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4051 - precision: 0.8255 - recall: 0.8511 - auc: 0.8969 - accuracy: 0.8223 - f_score: 0.8359 - val_loss: 0.6789 - val_precision: 0.9846 - val_recall: 0.6440 - val_auc: 0.8677 - val_accuracy: 0.6665 - val_f_score: 0.7758 - lr: 2.0000e-08
# Epoch 30/45
# 562/562 [==============================] - 66s 117ms/step - loss: 0.3976 - precision: 0.8219 - recall: 0.8515 - auc: 0.9000 - accuracy: 0.8200 - f_score: 0.8344 - val_loss: 0.6744 - val_precision: 0.9846 - val_recall: 0.6459 - val_auc: 0.8689 - val_accuracy: 0.6682 - val_f_score: 0.7786 - lr: 2.0000e-08
# Epoch 31/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.4008 - precision: 0.8190 - recall: 0.8503 - auc: 0.8986 - accuracy: 0.8175 - f_score: 0.8320 - val_loss: 0.6955 - val_precision: 0.9853 - val_recall: 0.6320 - val_auc: 0.8684 - val_accuracy: 0.6561 - val_f_score: 0.7684 - lr: 2.0000e-08
# Epoch 32/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4011 - precision: 0.8199 - recall: 0.8514 - auc: 0.8980 - accuracy: 0.8186 - f_score: 0.8326 - val_loss: 0.6756 - val_precision: 0.9845 - val_recall: 0.6421 - val_auc: 0.8691 - val_accuracy: 0.6648 - val_f_score: 0.7737 - lr: 2.0000e-08
# Epoch 33/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.3984 - precision: 0.8195 - recall: 0.8552 - auc: 0.8997 - accuracy: 0.8200 - f_score: 0.8344 - val_loss: 0.6723 - val_precision: 0.9846 - val_recall: 0.6446 - val_auc: 0.8691 - val_accuracy: 0.6670 - val_f_score: 0.7752 - lr: 2.0000e-09
# Epoch 34/45
# 562/562 [==============================] - 68s 121ms/step - loss: 0.4013 - precision: 0.8189 - recall: 0.8501 - auc: 0.8982 - accuracy: 0.8174 - f_score: 0.8319 - val_loss: 0.7090 - val_precision: 0.9850 - val_recall: 0.6188 - val_auc: 0.8688 - val_accuracy: 0.6441 - val_f_score: 0.7539 - lr: 2.0000e-09
# Epoch 35/45
# 562/562 [==============================] - 67s 120ms/step - loss: 0.4002 - precision: 0.8210 - recall: 0.8484 - auc: 0.8988 - accuracy: 0.8181 - f_score: 0.8326 - val_loss: 0.6803 - val_precision: 0.9845 - val_recall: 0.6408 - val_auc: 0.8685 - val_accuracy: 0.6636 - val_f_score: 0.7718 - lr: 2.0000e-09
# Epoch 36/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.3984 - precision: 0.8226 - recall: 0.8497 - auc: 0.8995 - accuracy: 0.8198 - f_score: 0.8337 - val_loss: 0.6668 - val_precision: 0.9847 - val_recall: 0.6484 - val_auc: 0.8693 - val_accuracy: 0.6705 - val_f_score: 0.7787 - lr: 2.0000e-09
# Epoch 37/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4054 - precision: 0.8227 - recall: 0.8502 - auc: 0.8963 - accuracy: 0.8200 - f_score: 0.8337 - val_loss: 0.6813 - val_precision: 0.9845 - val_recall: 0.6383 - val_auc: 0.8688 - val_accuracy: 0.6613 - val_f_score: 0.7730 - lr: 2.0000e-10
# Epoch 38/45
# 562/562 [==============================] - 67s 119ms/step - loss: 0.4026 - precision: 0.8203 - recall: 0.8526 - auc: 0.8974 - accuracy: 0.8194 - f_score: 0.8338 - val_loss: 0.6994 - val_precision: 0.9852 - val_recall: 0.6289 - val_auc: 0.8683 - val_accuracy: 0.6533 - val_f_score: 0.7653 - lr: 2.0000e-10
# Epoch 39/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4032 - precision: 0.8200 - recall: 0.8502 - auc: 0.8968 - accuracy: 0.8182 - f_score: 0.8320 - val_loss: 0.6912 - val_precision: 0.9853 - val_recall: 0.6333 - val_auc: 0.8684 - val_accuracy: 0.6573 - val_f_score: 0.7692 - lr: 2.0000e-10
# Epoch 40/45
# 562/562 [==============================] - 67s 118ms/step - loss: 0.4035 - precision: 0.8191 - recall: 0.8532 - auc: 0.8966 - accuracy: 0.8188 - f_score: 0.8330 - val_loss: 0.6898 - val_precision: 0.9845 - val_recall: 0.6389 - val_auc: 0.8673 - val_accuracy: 0.6619 - val_f_score: 0.7704 - lr: 2.0000e-10
# Epoch 41/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.4030 - precision: 0.8185 - recall: 0.8511 - auc: 0.8974 - accuracy: 0.8175 - f_score: 0.8320 - val_loss: 0.6891 - val_precision: 0.9844 - val_recall: 0.6364 - val_auc: 0.8682 - val_accuracy: 0.6596 - val_f_score: 0.7704 - lr: 2.0000e-11
# Epoch 42/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.3984 - precision: 0.8178 - recall: 0.8533 - auc: 0.8992 - accuracy: 0.8180 - f_score: 0.8325 - val_loss: 0.6722 - val_precision: 0.9846 - val_recall: 0.6452 - val_auc: 0.8694 - val_accuracy: 0.6676 - val_f_score: 0.7755 - lr: 2.0000e-11
# Epoch 43/45
# 562/562 [==============================] - 66s 117ms/step - loss: 0.4007 - precision: 0.8243 - recall: 0.8486 - auc: 0.8986 - accuracy: 0.8205 - f_score: 0.8340 - val_loss: 0.6928 - val_precision: 0.9843 - val_recall: 0.6333 - val_auc: 0.8691 - val_accuracy: 0.6567 - val_f_score: 0.7684 - lr: 2.0000e-11
# Epoch 44/45
# 562/562 [==============================] - 66s 117ms/step - loss: 0.4021 - precision: 0.8238 - recall: 0.8478 - auc: 0.8978 - accuracy: 0.8198 - f_score: 0.8328 - val_loss: 0.6763 - val_precision: 0.9845 - val_recall: 0.6396 - val_auc: 0.8682 - val_accuracy: 0.6625 - val_f_score: 0.7700 - lr: 2.0000e-11
# Epoch 45/45
# 562/562 [==============================] - 66s 118ms/step - loss: 0.3962 - precision: 0.8228 - recall: 0.8535 - auc: 0.9008 - accuracy: 0.8215 - f_score: 0.8352 - val_loss: 0.6808 - val_precision: 0.9845 - val_recall: 0.6415 - val_auc: 0.8686 - val_accuracy: 0.6642 - val_f_score: 0.7727 - lr: 2.0000e-12

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = resnet.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 55/55 [==============================] - 5s 70ms/step
# AUC: 0.5091529971339716
