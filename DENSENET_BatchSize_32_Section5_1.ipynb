# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_BatchSize_32_Section5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.Flatten())  # Use GlobalMaxPooling2D
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu'))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  flatten (Flatten)           (None, 3840)              0
#
#  batch_normalization (BatchN  (None, 3840)             15360
#  ormalization)
#
#  dropout (Dropout)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,306,497
# Trainable params: 1,975,809
# Non-trainable params: 18,330,688
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

dense.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 5433s 10s/step - loss: 0.5318 - precision: 0.7763 - recall: 0.7910 - auc: 0.8341 - accuracy: 0.7638 - f_score: 0.7802 - val_loss: 0.4473 - val_precision: 0.9690 - val_recall: 0.8072 - val_auc: 0.8559 - val_accuracy: 0.8008 - val_f_score: 0.8786 - lr: 0.0200
# Epoch 2/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.4396 - precision: 0.8012 - recall: 0.8302 - auc: 0.8764 - accuracy: 0.7969 - f_score: 0.8125 - val_loss: 0.2799 - val_precision: 0.9471 - val_recall: 0.9130 - val_auc: 0.8854 - val_accuracy: 0.8743 - val_f_score: 0.9287 - lr: 0.0200
# Epoch 3/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.4266 - precision: 0.8093 - recall: 0.8380 - auc: 0.8834 - accuracy: 0.8057 - f_score: 0.8204 - val_loss: 1.0938 - val_precision: 0.9984 - val_recall: 0.4008 - val_auc: 0.8518 - val_accuracy: 0.4535 - val_f_score: 0.5661 - lr: 0.0200
# Epoch 4/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.4238 - precision: 0.8131 - recall: 0.8413 - auc: 0.8856 - accuracy: 0.8097 - f_score: 0.8242 - val_loss: 0.9317 - val_precision: 0.9982 - val_recall: 0.3447 - val_auc: 0.8619 - val_accuracy: 0.4024 - val_f_score: 0.5063 - lr: 0.0200
# Epoch 5/45
# 562/562 [==============================] - 96s 171ms/step - loss: 0.4211 - precision: 0.8110 - recall: 0.8480 - auc: 0.8871 - accuracy: 0.8111 - f_score: 0.8265 - val_loss: 0.8563 - val_precision: 0.9976 - val_recall: 0.5135 - val_auc: 0.8911 - val_accuracy: 0.5557 - val_f_score: 0.6746 - lr: 0.0200
# Epoch 6/45
# 562/562 [==============================] - 96s 171ms/step - loss: 0.4349 - precision: 0.8099 - recall: 0.8349 - auc: 0.8801 - accuracy: 0.8049 - f_score: 0.8192 - val_loss: 0.7345 - val_precision: 0.9853 - val_recall: 0.6326 - val_auc: 0.8665 - val_accuracy: 0.6567 - val_f_score: 0.7630 - lr: 0.0200
# Epoch 7/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.4096 - precision: 0.8167 - recall: 0.8527 - auc: 0.8928 - accuracy: 0.8170 - f_score: 0.8316 - val_loss: 0.7547 - val_precision: 0.9915 - val_recall: 0.5892 - val_auc: 0.8805 - val_accuracy: 0.6211 - val_f_score: 0.7347 - lr: 0.0020
# Epoch 8/45
# 562/562 [==============================] - 96s 171ms/step - loss: 0.4032 - precision: 0.8242 - recall: 0.8537 - auc: 0.8962 - accuracy: 0.8225 - f_score: 0.8361 - val_loss: 0.6666 - val_precision: 0.9903 - val_recall: 0.6434 - val_auc: 0.8772 - val_accuracy: 0.6693 - val_f_score: 0.7762 - lr: 0.0020
# Epoch 9/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3972 - precision: 0.8265 - recall: 0.8608 - auc: 0.8996 - accuracy: 0.8271 - f_score: 0.8410 - val_loss: 0.6203 - val_precision: 0.9891 - val_recall: 0.6868 - val_auc: 0.8897 - val_accuracy: 0.7078 - val_f_score: 0.8076 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 93s 166ms/step - loss: 0.3967 - precision: 0.8187 - recall: 0.8579 - auc: 0.8998 - accuracy: 0.8205 - f_score: 0.8351 - val_loss: 0.7583 - val_precision: 0.9913 - val_recall: 0.5721 - val_auc: 0.8856 - val_accuracy: 0.6056 - val_f_score: 0.7219 - lr: 0.0020
# Epoch 11/45
# 562/562 [==============================] - 95s 170ms/step - loss: 0.3926 - precision: 0.8284 - recall: 0.8499 - auc: 0.9019 - accuracy: 0.8238 - f_score: 0.8367 - val_loss: 0.7267 - val_precision: 0.9916 - val_recall: 0.5929 - val_auc: 0.8842 - val_accuracy: 0.6246 - val_f_score: 0.7371 - lr: 2.0000e-04
# Epoch 12/45
# 562/562 [==============================] - 94s 168ms/step - loss: 0.3985 - precision: 0.8253 - recall: 0.8520 - auc: 0.8988 - accuracy: 0.8226 - f_score: 0.8360 - val_loss: 0.6773 - val_precision: 0.9892 - val_recall: 0.6339 - val_auc: 0.8855 - val_accuracy: 0.6602 - val_f_score: 0.7689 - lr: 2.0000e-04
# Epoch 13/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3934 - precision: 0.8239 - recall: 0.8580 - auc: 0.9015 - accuracy: 0.8242 - f_score: 0.8383 - val_loss: 0.7025 - val_precision: 0.9889 - val_recall: 0.6163 - val_auc: 0.8853 - val_accuracy: 0.6441 - val_f_score: 0.7536 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.3922 - precision: 0.8222 - recall: 0.8565 - auc: 0.9021 - accuracy: 0.8224 - f_score: 0.8372 - val_loss: 0.6859 - val_precision: 0.9882 - val_recall: 0.6352 - val_auc: 0.8841 - val_accuracy: 0.6607 - val_f_score: 0.7695 - lr: 2.0000e-04
# Epoch 15/45
# 562/562 [==============================] - 96s 171ms/step - loss: 0.3877 - precision: 0.8241 - recall: 0.8641 - auc: 0.9037 - accuracy: 0.8269 - f_score: 0.8410 - val_loss: 0.6895 - val_precision: 0.9882 - val_recall: 0.6314 - val_auc: 0.8851 - val_accuracy: 0.6573 - val_f_score: 0.7659 - lr: 2.0000e-05
# Epoch 16/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.3916 - precision: 0.8209 - recall: 0.8635 - auc: 0.9022 - accuracy: 0.8244 - f_score: 0.8392 - val_loss: 0.6900 - val_precision: 0.9881 - val_recall: 0.6301 - val_auc: 0.8831 - val_accuracy: 0.6561 - val_f_score: 0.7665 - lr: 2.0000e-05
# Epoch 17/45
# 562/562 [==============================] - 94s 168ms/step - loss: 0.3919 - precision: 0.8231 - recall: 0.8611 - auc: 0.9022 - accuracy: 0.8249 - f_score: 0.8394 - val_loss: 0.6808 - val_precision: 0.9883 - val_recall: 0.6383 - val_auc: 0.8837 - val_accuracy: 0.6636 - val_f_score: 0.7728 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 95s 168ms/step - loss: 0.3946 - precision: 0.8226 - recall: 0.8602 - auc: 0.9007 - accuracy: 0.8242 - f_score: 0.8383 - val_loss: 0.6974 - val_precision: 0.9880 - val_recall: 0.6244 - val_auc: 0.8842 - val_accuracy: 0.6510 - val_f_score: 0.7625 - lr: 2.0000e-05
# Epoch 19/45
# 562/562 [==============================] - 93s 166ms/step - loss: 0.3934 - precision: 0.8223 - recall: 0.8590 - auc: 0.9015 - accuracy: 0.8235 - f_score: 0.8374 - val_loss: 0.7019 - val_precision: 0.9880 - val_recall: 0.6200 - val_auc: 0.8828 - val_accuracy: 0.6470 - val_f_score: 0.7600 - lr: 2.0000e-06
# Epoch 20/45
# 562/562 [==============================] - 93s 166ms/step - loss: 0.3953 - precision: 0.8232 - recall: 0.8561 - auc: 0.9005 - accuracy: 0.8229 - f_score: 0.8370 - val_loss: 0.7077 - val_precision: 0.9879 - val_recall: 0.6181 - val_auc: 0.8846 - val_accuracy: 0.6452 - val_f_score: 0.7581 - lr: 2.0000e-06
# Epoch 21/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.3975 - precision: 0.8225 - recall: 0.8598 - auc: 0.8992 - accuracy: 0.8240 - f_score: 0.8382 - val_loss: 0.7066 - val_precision: 0.9879 - val_recall: 0.6169 - val_auc: 0.8829 - val_accuracy: 0.6441 - val_f_score: 0.7558 - lr: 2.0000e-06
# Epoch 22/45
# 562/562 [==============================] - 94s 166ms/step - loss: 0.3933 - precision: 0.8204 - recall: 0.8592 - auc: 0.9012 - accuracy: 0.8223 - f_score: 0.8375 - val_loss: 0.7162 - val_precision: 0.9878 - val_recall: 0.6137 - val_auc: 0.8839 - val_accuracy: 0.6412 - val_f_score: 0.7558 - lr: 2.0000e-06
# Epoch 23/45
# 562/562 [==============================] - 93s 166ms/step - loss: 0.3914 - precision: 0.8274 - recall: 0.8592 - auc: 0.9024 - accuracy: 0.8271 - f_score: 0.8410 - val_loss: 0.7040 - val_precision: 0.9879 - val_recall: 0.6188 - val_auc: 0.8831 - val_accuracy: 0.6458 - val_f_score: 0.7560 - lr: 2.0000e-07
# Epoch 24/45
# 562/562 [==============================] - 95s 168ms/step - loss: 0.3955 - precision: 0.8222 - recall: 0.8603 - auc: 0.9002 - accuracy: 0.8240 - f_score: 0.8380 - val_loss: 0.6965 - val_precision: 0.9881 - val_recall: 0.6257 - val_auc: 0.8828 - val_accuracy: 0.6521 - val_f_score: 0.7647 - lr: 2.0000e-07
# Epoch 25/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.3886 - precision: 0.8259 - recall: 0.8607 - auc: 0.9041 - accuracy: 0.8267 - f_score: 0.8407 - val_loss: 0.6875 - val_precision: 0.9882 - val_recall: 0.6326 - val_auc: 0.8826 - val_accuracy: 0.6584 - val_f_score: 0.7682 - lr: 2.0000e-07
# Epoch 26/45
# 562/562 [==============================] - 93s 165ms/step - loss: 0.3983 - precision: 0.8222 - recall: 0.8579 - auc: 0.8989 - accuracy: 0.8229 - f_score: 0.8373 - val_loss: 0.7027 - val_precision: 0.9879 - val_recall: 0.6188 - val_auc: 0.8833 - val_accuracy: 0.6458 - val_f_score: 0.7569 - lr: 2.0000e-07
# Epoch 27/45
# 562/562 [==============================] - 94s 168ms/step - loss: 0.3913 - precision: 0.8241 - recall: 0.8594 - auc: 0.9024 - accuracy: 0.8249 - f_score: 0.8392 - val_loss: 0.6948 - val_precision: 0.9881 - val_recall: 0.6276 - val_auc: 0.8831 - val_accuracy: 0.6538 - val_f_score: 0.7635 - lr: 2.0000e-08
# Epoch 28/45
# 562/562 [==============================] - 94s 168ms/step - loss: 0.3942 - precision: 0.8224 - recall: 0.8598 - auc: 0.9006 - accuracy: 0.8239 - f_score: 0.8382 - val_loss: 0.6924 - val_precision: 0.9881 - val_recall: 0.6263 - val_auc: 0.8839 - val_accuracy: 0.6527 - val_f_score: 0.7640 - lr: 2.0000e-08
# Epoch 29/45
# 562/562 [==============================] - 94s 166ms/step - loss: 0.3969 - precision: 0.8209 - recall: 0.8573 - auc: 0.8995 - accuracy: 0.8218 - f_score: 0.8368 - val_loss: 0.7006 - val_precision: 0.9880 - val_recall: 0.6219 - val_auc: 0.8837 - val_accuracy: 0.6487 - val_f_score: 0.7608 - lr: 2.0000e-08
# Epoch 30/45
# 562/562 [==============================] - 93s 165ms/step - loss: 0.3928 - precision: 0.8227 - recall: 0.8608 - auc: 0.9019 - accuracy: 0.8245 - f_score: 0.8387 - val_loss: 0.6963 - val_precision: 0.9881 - val_recall: 0.6257 - val_auc: 0.8832 - val_accuracy: 0.6521 - val_f_score: 0.7647 - lr: 2.0000e-08
# Epoch 31/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3923 - precision: 0.8240 - recall: 0.8552 - auc: 0.9017 - accuracy: 0.8230 - f_score: 0.8364 - val_loss: 0.6881 - val_precision: 0.9882 - val_recall: 0.6314 - val_auc: 0.8837 - val_accuracy: 0.6573 - val_f_score: 0.7680 - lr: 2.0000e-09
# Epoch 32/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.3932 - precision: 0.8237 - recall: 0.8614 - auc: 0.9019 - accuracy: 0.8254 - f_score: 0.8392 - val_loss: 0.6837 - val_precision: 0.9883 - val_recall: 0.6371 - val_auc: 0.8836 - val_accuracy: 0.6625 - val_f_score: 0.7703 - lr: 2.0000e-09
# Epoch 33/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.3937 - precision: 0.8216 - recall: 0.8569 - auc: 0.9003 - accuracy: 0.8221 - f_score: 0.8363 - val_loss: 0.6770 - val_precision: 0.9883 - val_recall: 0.6402 - val_auc: 0.8838 - val_accuracy: 0.6653 - val_f_score: 0.7713 - lr: 2.0000e-09
# Epoch 34/45
# 562/562 [==============================] - 95s 170ms/step - loss: 0.3890 - precision: 0.8259 - recall: 0.8618 - auc: 0.9037 - accuracy: 0.8272 - f_score: 0.8415 - val_loss: 0.7025 - val_precision: 0.9880 - val_recall: 0.6200 - val_auc: 0.8832 - val_accuracy: 0.6470 - val_f_score: 0.7588 - lr: 2.0000e-09
# Epoch 35/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.3932 - precision: 0.8230 - recall: 0.8611 - auc: 0.9011 - accuracy: 0.8248 - f_score: 0.8390 - val_loss: 0.7139 - val_precision: 0.9879 - val_recall: 0.6150 - val_auc: 0.8835 - val_accuracy: 0.6424 - val_f_score: 0.7546 - lr: 2.0000e-10
# Epoch 36/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3931 - precision: 0.8236 - recall: 0.8562 - auc: 0.9017 - accuracy: 0.8232 - f_score: 0.8372 - val_loss: 0.6972 - val_precision: 0.9881 - val_recall: 0.6263 - val_auc: 0.8832 - val_accuracy: 0.6527 - val_f_score: 0.7623 - lr: 2.0000e-10
# Epoch 37/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3941 - precision: 0.8231 - recall: 0.8584 - auc: 0.9013 - accuracy: 0.8238 - f_score: 0.8383 - val_loss: 0.6839 - val_precision: 0.9882 - val_recall: 0.6339 - val_auc: 0.8836 - val_accuracy: 0.6596 - val_f_score: 0.7703 - lr: 2.0000e-10
# Epoch 38/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.3923 - precision: 0.8265 - recall: 0.8624 - auc: 0.9017 - accuracy: 0.8278 - f_score: 0.8416 - val_loss: 0.7055 - val_precision: 0.9879 - val_recall: 0.6188 - val_auc: 0.8832 - val_accuracy: 0.6458 - val_f_score: 0.7571 - lr: 2.0000e-10
# Epoch 39/45
# 562/562 [==============================] - 95s 168ms/step - loss: 0.3924 - precision: 0.8230 - recall: 0.8605 - auc: 0.9016 - accuracy: 0.8246 - f_score: 0.8389 - val_loss: 0.7074 - val_precision: 0.9879 - val_recall: 0.6175 - val_auc: 0.8848 - val_accuracy: 0.6447 - val_f_score: 0.7540 - lr: 2.0000e-11
# Epoch 40/45
# 562/562 [==============================] - 94s 166ms/step - loss: 0.3989 - precision: 0.8198 - recall: 0.8534 - auc: 0.8981 - accuracy: 0.8194 - f_score: 0.8334 - val_loss: 0.6790 - val_precision: 0.9884 - val_recall: 0.6427 - val_auc: 0.8837 - val_accuracy: 0.6676 - val_f_score: 0.7767 - lr: 2.0000e-11
# Epoch 41/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3897 - precision: 0.8265 - recall: 0.8612 - auc: 0.9034 - accuracy: 0.8273 - f_score: 0.8418 - val_loss: 0.7075 - val_precision: 0.9879 - val_recall: 0.6181 - val_auc: 0.8832 - val_accuracy: 0.6452 - val_f_score: 0.7569 - lr: 2.0000e-11
# Epoch 42/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.3945 - precision: 0.8245 - recall: 0.8614 - auc: 0.9011 - accuracy: 0.8260 - f_score: 0.8397 - val_loss: 0.7054 - val_precision: 0.9889 - val_recall: 0.6181 - val_auc: 0.8833 - val_accuracy: 0.6458 - val_f_score: 0.7555 - lr: 2.0000e-11
# Epoch 43/45
# 562/562 [==============================] - 95s 168ms/step - loss: 0.3887 - precision: 0.8213 - recall: 0.8628 - auc: 0.9034 - accuracy: 0.8244 - f_score: 0.8386 - val_loss: 0.6933 - val_precision: 0.9881 - val_recall: 0.6276 - val_auc: 0.8836 - val_accuracy: 0.6538 - val_f_score: 0.7649 - lr: 2.0000e-12
# Epoch 44/45
# 562/562 [==============================] - 83s 148ms/step - loss: 0.3966 - precision: 0.8205 - recall: 0.8614 - auc: 0.8995 - accuracy: 0.8233 - f_score: 0.8375 - val_loss: 0.6912 - val_precision: 0.9881 - val_recall: 0.6301 - val_auc: 0.8838 - val_accuracy: 0.6561 - val_f_score: 0.7654 - lr: 2.0000e-12
# Epoch 45/45
# 562/562 [==============================] - 82s 146ms/step - loss: 0.3929 - precision: 0.8237 - recall: 0.8581 - auc: 0.9016 - accuracy: 0.8240 - f_score: 0.8384 - val_loss: 0.7025 - val_precision: 0.9880 - val_recall: 0.6200 - val_auc: 0.8840 - val_accuracy: 0.6470 - val_f_score: 0.7564 - lr: 2.0000e-12

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = dense.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 55/55 [==============================] - 11s 130ms/step
# AUC: 0.4549464398235664
