# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_More_Aug_Section5_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   vertical_flip= True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.Flatten())
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  flatten (Flatten)           (None, 3840)              0
#
#  batch_normalization (BatchN  (None, 3840)             15360
#  ormalization)
#
#  dropout (Dropout)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,306,497
# Trainable params: 1,975,809
# Non-trainable params: 18,330,688
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.002)

dense.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3425s 6s/step - loss: 20.2356 - precision: 0.6957 - recall: 0.7721 - auc: 0.7489 - accuracy: 0.6943 - f_score: 0.7276 - val_loss: 5.4948 - val_precision: 0.9311 - val_recall: 0.9445 - val_auc: 0.7364 - val_accuracy: 0.8858 - val_f_score: 0.9374 - lr: 0.0020
# Epoch 2/45
# 562/562 [==============================] - 83s 147ms/step - loss: 5.2076 - precision: 0.7071 - recall: 0.7931 - auc: 0.7794 - accuracy: 0.7107 - f_score: 0.7443 - val_loss: 5.0443 - val_precision: 0.9462 - val_recall: 0.8311 - val_auc: 0.7509 - val_accuracy: 0.8031 - val_f_score: 0.8835 - lr: 0.0020
# Epoch 3/45
# 562/562 [==============================] - 82s 146ms/step - loss: 5.1551 - precision: 0.6990 - recall: 0.7869 - auc: 0.7675 - accuracy: 0.7017 - f_score: 0.7365 - val_loss: 5.0900 - val_precision: 0.9436 - val_recall: 0.8639 - val_auc: 0.7493 - val_accuracy: 0.8289 - val_f_score: 0.8994 - lr: 0.0020
# Epoch 4/45
# 562/562 [==============================] - 83s 147ms/step - loss: 5.1938 - precision: 0.6996 - recall: 0.7989 - auc: 0.7712 - accuracy: 0.7060 - f_score: 0.7419 - val_loss: 5.2715 - val_precision: 0.9552 - val_recall: 0.6578 - val_auc: 0.7671 - val_accuracy: 0.6602 - val_f_score: 0.7762 - lr: 0.0020
# Epoch 5/45
# 562/562 [==============================] - 81s 144ms/step - loss: 5.2148 - precision: 0.7018 - recall: 0.7877 - auc: 0.7710 - accuracy: 0.7044 - f_score: 0.7393 - val_loss: 5.0729 - val_precision: 0.9365 - val_recall: 0.9206 - val_auc: 0.7737 - val_accuracy: 0.8708 - val_f_score: 0.9275 - lr: 0.0020
# Epoch 6/45
# 562/562 [==============================] - 81s 144ms/step - loss: 1.1478 - precision: 0.7028 - recall: 0.8180 - auc: 0.7827 - accuracy: 0.7147 - f_score: 0.7525 - val_loss: 1.0125 - val_precision: 0.9417 - val_recall: 0.8557 - val_auc: 0.7332 - val_accuracy: 0.8203 - val_f_score: 0.8953 - lr: 2.0000e-04
# Epoch 7/45
# 562/562 [==============================] - 83s 147ms/step - loss: 1.0780 - precision: 0.7057 - recall: 0.8068 - auc: 0.7816 - accuracy: 0.7137 - f_score: 0.7495 - val_loss: 1.0287 - val_precision: 0.9444 - val_recall: 0.8248 - val_auc: 0.7402 - val_accuracy: 0.7962 - val_f_score: 0.8795 - lr: 2.0000e-04
# Epoch 8/45
# 562/562 [==============================] - 81s 144ms/step - loss: 1.0775 - precision: 0.7073 - recall: 0.7995 - auc: 0.7813 - accuracy: 0.7129 - f_score: 0.7473 - val_loss: 1.0163 - val_precision: 0.9431 - val_recall: 0.8154 - val_auc: 0.7263 - val_accuracy: 0.7870 - val_f_score: 0.8726 - lr: 2.0000e-04
# Epoch 9/45
# 562/562 [==============================] - 82s 145ms/step - loss: 1.0768 - precision: 0.7081 - recall: 0.8055 - auc: 0.7818 - accuracy: 0.7154 - f_score: 0.7500 - val_loss: 1.0052 - val_precision: 0.9443 - val_recall: 0.8330 - val_auc: 0.7398 - val_accuracy: 0.8031 - val_f_score: 0.8824 - lr: 2.0000e-04
# Epoch 10/45
# 562/562 [==============================] - 82s 147ms/step - loss: 0.6514 - precision: 0.7131 - recall: 0.8068 - auc: 0.7829 - accuracy: 0.7202 - f_score: 0.7537 - val_loss: 0.5803 - val_precision: 0.9431 - val_recall: 0.8362 - val_auc: 0.7377 - val_accuracy: 0.8048 - val_f_score: 0.8847 - lr: 2.0000e-05
# Epoch 11/45
# 562/562 [==============================] - 82s 145ms/step - loss: 0.6412 - precision: 0.7101 - recall: 0.8087 - auc: 0.7842 - accuracy: 0.7182 - f_score: 0.7525 - val_loss: 0.5771 - val_precision: 0.9433 - val_recall: 0.8393 - val_auc: 0.7373 - val_accuracy: 0.8077 - val_f_score: 0.8872 - lr: 2.0000e-05
# Epoch 12/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.6413 - precision: 0.7116 - recall: 0.7964 - auc: 0.7835 - accuracy: 0.7155 - f_score: 0.7481 - val_loss: 0.5820 - val_precision: 0.9425 - val_recall: 0.8267 - val_auc: 0.7363 - val_accuracy: 0.7962 - val_f_score: 0.8791 - lr: 2.0000e-05
# Epoch 13/45
# 562/562 [==============================] - 82s 146ms/step - loss: 0.6422 - precision: 0.7103 - recall: 0.7975 - auc: 0.7828 - accuracy: 0.7148 - f_score: 0.7484 - val_loss: 0.5872 - val_precision: 0.9422 - val_recall: 0.8223 - val_auc: 0.7365 - val_accuracy: 0.7922 - val_f_score: 0.8774 - lr: 2.0000e-05
# Epoch 14/45
# 562/562 [==============================] - 82s 145ms/step - loss: 0.5979 - precision: 0.7152 - recall: 0.8038 - auc: 0.7862 - accuracy: 0.7210 - f_score: 0.7537 - val_loss: 0.5270 - val_precision: 0.9428 - val_recall: 0.8519 - val_auc: 0.7323 - val_accuracy: 0.8180 - val_f_score: 0.8937 - lr: 2.0000e-06
# Epoch 15/45
# 562/562 [==============================] - 81s 145ms/step - loss: 0.5969 - precision: 0.7159 - recall: 0.8060 - auc: 0.7857 - accuracy: 0.7223 - f_score: 0.7552 - val_loss: 0.5347 - val_precision: 0.9426 - val_recall: 0.8374 - val_auc: 0.7350 - val_accuracy: 0.8054 - val_f_score: 0.8853 - lr: 2.0000e-06
# Epoch 16/45
# 562/562 [==============================] - 82s 146ms/step - loss: 0.5997 - precision: 0.7093 - recall: 0.8004 - auc: 0.7818 - accuracy: 0.7149 - f_score: 0.7486 - val_loss: 0.5401 - val_precision: 0.9427 - val_recall: 0.8292 - val_auc: 0.7327 - val_accuracy: 0.7985 - val_f_score: 0.8807 - lr: 2.0000e-06
# Epoch 17/45
# 562/562 [==============================] - 81s 145ms/step - loss: 0.5989 - precision: 0.7137 - recall: 0.7992 - auc: 0.7843 - accuracy: 0.7182 - f_score: 0.7509 - val_loss: 0.5477 - val_precision: 0.9434 - val_recall: 0.8185 - val_auc: 0.7333 - val_accuracy: 0.7899 - val_f_score: 0.8745 - lr: 2.0000e-06
# Epoch 18/45
# 562/562 [==============================] - 82s 145ms/step - loss: 0.5919 - precision: 0.7111 - recall: 0.8003 - auc: 0.7851 - accuracy: 0.7164 - f_score: 0.7502 - val_loss: 0.5439 - val_precision: 0.9433 - val_recall: 0.8173 - val_auc: 0.7369 - val_accuracy: 0.7887 - val_f_score: 0.8728 - lr: 2.0000e-07
# Epoch 19/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.5982 - precision: 0.7092 - recall: 0.7972 - auc: 0.7794 - accuracy: 0.7138 - f_score: 0.7476 - val_loss: 0.5360 - val_precision: 0.9428 - val_recall: 0.8311 - val_auc: 0.7360 - val_accuracy: 0.8002 - val_f_score: 0.8809 - lr: 2.0000e-07
# Epoch 20/45
# 562/562 [==============================] - 81s 145ms/step - loss: 0.5915 - precision: 0.7174 - recall: 0.8014 - auc: 0.7870 - accuracy: 0.7221 - f_score: 0.7536 - val_loss: 0.5344 - val_precision: 0.9423 - val_recall: 0.8336 - val_auc: 0.7324 - val_accuracy: 0.8020 - val_f_score: 0.8825 - lr: 2.0000e-07
# Epoch 21/45
# 562/562 [==============================] - 83s 147ms/step - loss: 0.5983 - precision: 0.7091 - recall: 0.8016 - auc: 0.7796 - accuracy: 0.7151 - f_score: 0.7489 - val_loss: 0.5345 - val_precision: 0.9423 - val_recall: 0.8330 - val_auc: 0.7339 - val_accuracy: 0.8014 - val_f_score: 0.8828 - lr: 2.0000e-07
# Epoch 22/45
# 562/562 [==============================] - 85s 151ms/step - loss: 0.5901 - precision: 0.7115 - recall: 0.8005 - auc: 0.7864 - accuracy: 0.7168 - f_score: 0.7501 - val_loss: 0.5336 - val_precision: 0.9429 - val_recall: 0.8318 - val_auc: 0.7358 - val_accuracy: 0.8008 - val_f_score: 0.8830 - lr: 2.0000e-08
# Epoch 23/45
# 562/562 [==============================] - 81s 145ms/step - loss: 0.5942 - precision: 0.7140 - recall: 0.7989 - auc: 0.7832 - accuracy: 0.7184 - f_score: 0.7506 - val_loss: 0.5347 - val_precision: 0.9429 - val_recall: 0.8318 - val_auc: 0.7323 - val_accuracy: 0.8008 - val_f_score: 0.8822 - lr: 2.0000e-08
# Epoch 24/45
# 562/562 [==============================] - 83s 148ms/step - loss: 0.5918 - precision: 0.7141 - recall: 0.8008 - auc: 0.7847 - accuracy: 0.7191 - f_score: 0.7514 - val_loss: 0.5268 - val_precision: 0.9423 - val_recall: 0.8444 - val_auc: 0.7336 - val_accuracy: 0.8111 - val_f_score: 0.8897 - lr: 2.0000e-08
# Epoch 25/45
# 562/562 [==============================] - 83s 147ms/step - loss: 0.5922 - precision: 0.7126 - recall: 0.7995 - auc: 0.7844 - accuracy: 0.7174 - f_score: 0.7505 - val_loss: 0.5381 - val_precision: 0.9425 - val_recall: 0.8267 - val_auc: 0.7346 - val_accuracy: 0.7962 - val_f_score: 0.8787 - lr: 2.0000e-08
# Epoch 26/45
# 562/562 [==============================] - 81s 144ms/step - loss: 0.5915 - precision: 0.7112 - recall: 0.8027 - auc: 0.7860 - accuracy: 0.7172 - f_score: 0.7513 - val_loss: 0.5325 - val_precision: 0.9430 - val_recall: 0.8336 - val_auc: 0.7345 - val_accuracy: 0.8025 - val_f_score: 0.8835 - lr: 2.0000e-09

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
