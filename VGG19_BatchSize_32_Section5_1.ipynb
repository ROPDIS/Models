# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/VGG19_BatchSize_32_Section5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
VGG = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.VGG19(
    include_top=False,
    weights="imagenet",
    input_shape=(60,80,3),
    pooling=None)

for layer in pretrained_model.layers:
    layer.trainable = False

VGG.add(pretrained_model)

VGG.add(tf.keras.layers.Flatten())  # Use GlobalMaxPooling2D
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(512, activation='relu'))
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(1, activation='sigmoid'))

VGG.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 1, 2, 512)         20024384
#
#  flatten (Flatten)           (None, 1024)              0
#
#  batch_normalization (BatchN  (None, 1024)             4096
#  ormalization)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,555,841
# Trainable params: 528,385
# Non-trainable params: 20,027,456
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.002)

VGG.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history = VGG.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 3291s 6s/step - loss: 0.5414 - precision: 0.7641 - recall: 0.7850 - auc: 0.8206 - accuracy: 0.7528 - f_score: 0.7711 - val_loss: 0.7879 - val_precision: 0.9877 - val_recall: 0.5066 - val_auc: 0.8402 - val_accuracy: 0.5448 - val_f_score: 0.6642 - lr: 0.0020
# Epoch 2/45
# 562/562 [==============================] - 124s 220ms/step - loss: 0.4851 - precision: 0.7813 - recall: 0.8115 - auc: 0.8476 - accuracy: 0.7753 - f_score: 0.7930 - val_loss: 1.1057 - val_precision: 0.9899 - val_recall: 0.3075 - val_auc: 0.8428 - val_accuracy: 0.3662 - val_f_score: 0.4594 - lr: 0.0020
# Epoch 3/45
# 562/562 [==============================] - 120s 214ms/step - loss: 0.4804 - precision: 0.7874 - recall: 0.8016 - auc: 0.8510 - accuracy: 0.7758 - f_score: 0.7921 - val_loss: 0.7208 - val_precision: 0.9820 - val_recall: 0.5507 - val_auc: 0.8516 - val_accuracy: 0.5815 - val_f_score: 0.6984 - lr: 0.0020
# Epoch 4/45
# 562/562 [==============================] - 121s 216ms/step - loss: 0.4714 - precision: 0.7887 - recall: 0.8124 - auc: 0.8565 - accuracy: 0.7810 - f_score: 0.7975 - val_loss: 0.9030 - val_precision: 0.9872 - val_recall: 0.4871 - val_auc: 0.8579 - val_accuracy: 0.5270 - val_f_score: 0.6478 - lr: 0.0020
# Epoch 5/45
# 562/562 [==============================] - 118s 210ms/step - loss: 0.4670 - precision: 0.7937 - recall: 0.8068 - auc: 0.8591 - accuracy: 0.7822 - f_score: 0.7979 - val_loss: 0.8218 - val_precision: 0.9865 - val_recall: 0.5047 - val_auc: 0.8589 - val_accuracy: 0.5425 - val_f_score: 0.6637 - lr: 0.0020
# Epoch 6/45
# 562/562 [==============================] - 116s 206ms/step - loss: 0.4576 - precision: 0.7988 - recall: 0.8174 - auc: 0.8658 - accuracy: 0.7901 - f_score: 0.8055 - val_loss: 0.7656 - val_precision: 0.9835 - val_recall: 0.5255 - val_auc: 0.8541 - val_accuracy: 0.5597 - val_f_score: 0.6808 - lr: 0.0020
# Epoch 7/45
# 562/562 [==============================] - 116s 207ms/step - loss: 0.4579 - precision: 0.7954 - recall: 0.8186 - auc: 0.8651 - accuracy: 0.7881 - f_score: 0.8037 - val_loss: 0.7541 - val_precision: 0.9864 - val_recall: 0.5488 - val_auc: 0.8901 - val_accuracy: 0.5821 - val_f_score: 0.6996 - lr: 0.0020
# Epoch 8/45
# 562/562 [==============================] - 118s 210ms/step - loss: 0.4528 - precision: 0.7961 - recall: 0.8200 - auc: 0.8684 - accuracy: 0.7893 - f_score: 0.8052 - val_loss: 1.1525 - val_precision: 0.9885 - val_recall: 0.3245 - val_auc: 0.8566 - val_accuracy: 0.3812 - val_f_score: 0.4837 - lr: 0.0020
# Epoch 9/45
# 562/562 [==============================] - 119s 211ms/step - loss: 0.4510 - precision: 0.7967 - recall: 0.8181 - auc: 0.8690 - accuracy: 0.7889 - f_score: 0.8047 - val_loss: 1.0323 - val_precision: 0.9879 - val_recall: 0.4619 - val_auc: 0.8710 - val_accuracy: 0.5046 - val_f_score: 0.6233 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 120s 213ms/step - loss: 0.4489 - precision: 0.7991 - recall: 0.8227 - auc: 0.8703 - accuracy: 0.7924 - f_score: 0.8083 - val_loss: 1.4214 - val_precision: 0.9852 - val_recall: 0.2520 - val_auc: 0.8615 - val_accuracy: 0.3152 - val_f_score: 0.3965 - lr: 0.0020
# Epoch 11/45
# 562/562 [==============================] - 117s 209ms/step - loss: 0.4502 - precision: 0.8024 - recall: 0.8213 - auc: 0.8698 - accuracy: 0.7942 - f_score: 0.8088 - val_loss: 1.0485 - val_precision: 0.9886 - val_recall: 0.3837 - val_auc: 0.8748 - val_accuracy: 0.4346 - val_f_score: 0.5460 - lr: 0.0020
# Epoch 12/45
# 562/562 [==============================] - 113s 201ms/step - loss: 0.4366 - precision: 0.8085 - recall: 0.8192 - auc: 0.8777 - accuracy: 0.7974 - f_score: 0.8115 - val_loss: 0.9802 - val_precision: 0.9911 - val_recall: 0.4197 - val_auc: 0.8841 - val_accuracy: 0.4679 - val_f_score: 0.5827 - lr: 2.0000e-04
# Epoch 13/45
# 562/562 [==============================] - 114s 203ms/step - loss: 0.4278 - precision: 0.8073 - recall: 0.8290 - auc: 0.8826 - accuracy: 0.8007 - f_score: 0.8156 - val_loss: 0.9661 - val_precision: 0.9916 - val_recall: 0.4461 - val_auc: 0.8826 - val_accuracy: 0.4920 - val_f_score: 0.6065 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 115s 204ms/step - loss: 0.4270 - precision: 0.8151 - recall: 0.8334 - auc: 0.8839 - accuracy: 0.8078 - f_score: 0.8219 - val_loss: 0.9493 - val_precision: 0.9904 - val_recall: 0.4543 - val_auc: 0.8835 - val_accuracy: 0.4989 - val_f_score: 0.6150 - lr: 2.0000e-04
# Epoch 15/45
# 562/562 [==============================] - 117s 208ms/step - loss: 0.4342 - precision: 0.8111 - recall: 0.8280 - auc: 0.8795 - accuracy: 0.8028 - f_score: 0.8165 - val_loss: 0.9334 - val_precision: 0.9904 - val_recall: 0.4556 - val_auc: 0.8936 - val_accuracy: 0.5000 - val_f_score: 0.6179 - lr: 2.0000e-04
# Epoch 16/45
# 562/562 [==============================] - 117s 209ms/step - loss: 0.4243 - precision: 0.8172 - recall: 0.8339 - auc: 0.8854 - accuracy: 0.8094 - f_score: 0.8232 - val_loss: 0.9330 - val_precision: 0.9905 - val_recall: 0.4594 - val_auc: 0.8918 - val_accuracy: 0.5034 - val_f_score: 0.6194 - lr: 2.0000e-05
# Epoch 17/45
# 562/562 [==============================] - 119s 212ms/step - loss: 0.4287 - precision: 0.8117 - recall: 0.8326 - auc: 0.8827 - accuracy: 0.8052 - f_score: 0.8197 - val_loss: 0.9236 - val_precision: 0.9905 - val_recall: 0.4612 - val_auc: 0.8916 - val_accuracy: 0.5052 - val_f_score: 0.6229 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 118s 210ms/step - loss: 0.4284 - precision: 0.8128 - recall: 0.8354 - auc: 0.8832 - accuracy: 0.8071 - f_score: 0.8213 - val_loss: 0.8924 - val_precision: 0.9908 - val_recall: 0.4732 - val_auc: 0.8917 - val_accuracy: 0.5161 - val_f_score: 0.6318 - lr: 2.0000e-05
# Epoch 19/45
# 562/562 [==============================] - 117s 208ms/step - loss: 0.4257 - precision: 0.8088 - recall: 0.8344 - auc: 0.8847 - accuracy: 0.8040 - f_score: 0.8187 - val_loss: 0.9451 - val_precision: 0.9903 - val_recall: 0.4493 - val_auc: 0.8897 - val_accuracy: 0.4943 - val_f_score: 0.6157 - lr: 2.0000e-05
# Epoch 20/45
# 562/562 [==============================] - 118s 210ms/step - loss: 0.4249 - precision: 0.8110 - recall: 0.8315 - auc: 0.8844 - accuracy: 0.8042 - f_score: 0.8181 - val_loss: 0.9230 - val_precision: 0.9904 - val_recall: 0.4568 - val_auc: 0.8899 - val_accuracy: 0.5011 - val_f_score: 0.6206 - lr: 2.0000e-06
# Epoch 21/45
# 562/562 [==============================] - 118s 209ms/step - loss: 0.4247 - precision: 0.8124 - recall: 0.8379 - auc: 0.8850 - accuracy: 0.8078 - f_score: 0.8214 - val_loss: 0.9159 - val_precision: 0.9892 - val_recall: 0.4606 - val_auc: 0.8900 - val_accuracy: 0.5040 - val_f_score: 0.6233 - lr: 2.0000e-06
# Epoch 22/45
# 562/562 [==============================] - 116s 206ms/step - loss: 0.4232 - precision: 0.8162 - recall: 0.8294 - auc: 0.8858 - accuracy: 0.8068 - f_score: 0.8201 - val_loss: 0.9169 - val_precision: 0.9892 - val_recall: 0.4638 - val_auc: 0.8878 - val_accuracy: 0.5069 - val_f_score: 0.6244 - lr: 2.0000e-06
# Epoch 23/45
# 562/562 [==============================] - 114s 202ms/step - loss: 0.4263 - precision: 0.8105 - recall: 0.8339 - auc: 0.8842 - accuracy: 0.8049 - f_score: 0.8198 - val_loss: 0.9461 - val_precision: 0.9902 - val_recall: 0.4442 - val_auc: 0.8886 - val_accuracy: 0.4897 - val_f_score: 0.6044 - lr: 2.0000e-06
# Epoch 24/45
# 562/562 [==============================] - 117s 208ms/step - loss: 0.4259 - precision: 0.8161 - recall: 0.8324 - auc: 0.8846 - accuracy: 0.8080 - f_score: 0.8218 - val_loss: 0.9402 - val_precision: 0.9904 - val_recall: 0.4531 - val_auc: 0.8905 - val_accuracy: 0.4977 - val_f_score: 0.6167 - lr: 2.0000e-07
# Epoch 25/45
# 562/562 [==============================] - 116s 206ms/step - loss: 0.4235 - precision: 0.8138 - recall: 0.8333 - auc: 0.8856 - accuracy: 0.8068 - f_score: 0.8213 - val_loss: 0.9455 - val_precision: 0.9902 - val_recall: 0.4449 - val_auc: 0.8877 - val_accuracy: 0.4902 - val_f_score: 0.6086 - lr: 2.0000e-07
# Epoch 26/45
# 562/562 [==============================] - 113s 201ms/step - loss: 0.4258 - precision: 0.8146 - recall: 0.8316 - auc: 0.8846 - accuracy: 0.8067 - f_score: 0.8207 - val_loss: 0.9240 - val_precision: 0.9904 - val_recall: 0.4549 - val_auc: 0.8897 - val_accuracy: 0.4994 - val_f_score: 0.6189 - lr: 2.0000e-07
# Epoch 27/45
# 562/562 [==============================] - 112s 200ms/step - loss: 0.4305 - precision: 0.8093 - recall: 0.8301 - auc: 0.8816 - accuracy: 0.8024 - f_score: 0.8165 - val_loss: 0.9397 - val_precision: 0.9902 - val_recall: 0.4449 - val_auc: 0.8897 - val_accuracy: 0.4902 - val_f_score: 0.6086 - lr: 2.0000e-07
# Epoch 28/45
# 562/562 [==============================] - 112s 199ms/step - loss: 0.4321 - precision: 0.8117 - recall: 0.8285 - auc: 0.8811 - accuracy: 0.8035 - f_score: 0.8173 - val_loss: 0.9159 - val_precision: 0.9906 - val_recall: 0.4631 - val_auc: 0.8895 - val_accuracy: 0.5069 - val_f_score: 0.6222 - lr: 2.0000e-08
# Epoch 29/45
# 562/562 [==============================] - 110s 196ms/step - loss: 0.4236 - precision: 0.8187 - recall: 0.8323 - auc: 0.8858 - accuracy: 0.8097 - f_score: 0.8230 - val_loss: 0.9099 - val_precision: 0.9893 - val_recall: 0.4644 - val_auc: 0.8881 - val_accuracy: 0.5075 - val_f_score: 0.6283 - lr: 2.0000e-08
# Epoch 30/45
# 562/562 [==============================] - 110s 196ms/step - loss: 0.4209 - precision: 0.8137 - recall: 0.8333 - auc: 0.8868 - accuracy: 0.8068 - f_score: 0.8204 - val_loss: 0.9237 - val_precision: 0.9891 - val_recall: 0.4594 - val_auc: 0.8890 - val_accuracy: 0.5029 - val_f_score: 0.6236 - lr: 2.0000e-08
# Epoch 31/45
# 562/562 [==============================] - 114s 203ms/step - loss: 0.4256 - precision: 0.8144 - recall: 0.8316 - auc: 0.8844 - accuracy: 0.8066 - f_score: 0.8206 - val_loss: 0.9383 - val_precision: 0.9902 - val_recall: 0.4468 - val_auc: 0.8885 - val_accuracy: 0.4920 - val_f_score: 0.6093 - lr: 2.0000e-08
# Epoch 32/45
# 562/562 [==============================] - 114s 203ms/step - loss: 0.4258 - precision: 0.8136 - recall: 0.8318 - auc: 0.8843 - accuracy: 0.8061 - f_score: 0.8204 - val_loss: 0.8912 - val_precision: 0.9896 - val_recall: 0.4808 - val_auc: 0.8884 - val_accuracy: 0.5224 - val_f_score: 0.6402 - lr: 2.0000e-09

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = VGG.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 55/55 [==============================] - 9s 153ms/step
# AUC: 0.4749720511413298
