# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_BatchSize_16_Section5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=16,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 16,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.Flatten())  # Use GlobalMaxPooling2D
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu'))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  flatten (Flatten)           (None, 3840)              0
#
#  batch_normalization (BatchN  (None, 3840)             15360
#  ormalization)
#
#  dropout (Dropout)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,306,497
# Trainable params: 1,975,809
# Non-trainable params: 18,330,688
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

dense.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 1124/1124 [==============================] - 3151s 3s/step - loss: 0.5400 - precision: 0.7676 - recall: 0.7873 - auc: 0.8264 - accuracy: 0.7562 - f_score: 0.7711 - val_loss: 0.3961 - val_precision: 0.9638 - val_recall: 0.8393 - val_auc: 0.8563 - val_accuracy: 0.8249 - val_f_score: 0.8931 - lr: 0.0200
# Epoch 2/45
# 1124/1124 [==============================] - 148s 131ms/step - loss: 0.4639 - precision: 0.7936 - recall: 0.8208 - auc: 0.8615 - accuracy: 0.7878 - f_score: 0.8001 - val_loss: 0.8539 - val_precision: 0.9936 - val_recall: 0.4915 - val_auc: 0.8496 - val_accuracy: 0.5339 - val_f_score: 0.6511 - lr: 0.0200
# Epoch 3/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4582 - precision: 0.7975 - recall: 0.8208 - auc: 0.8664 - accuracy: 0.7905 - f_score: 0.8038 - val_loss: 0.7888 - val_precision: 0.9908 - val_recall: 0.5444 - val_auc: 0.8663 - val_accuracy: 0.5804 - val_f_score: 0.6935 - lr: 0.0200
# Epoch 4/45
# 1124/1124 [==============================] - 148s 132ms/step - loss: 0.4509 - precision: 0.8022 - recall: 0.8226 - auc: 0.8703 - accuracy: 0.7945 - f_score: 0.8067 - val_loss: 0.5461 - val_precision: 0.9860 - val_recall: 0.7114 - val_auc: 0.8778 - val_accuracy: 0.7279 - val_f_score: 0.8219 - lr: 0.0200
# Epoch 5/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4523 - precision: 0.7976 - recall: 0.8277 - auc: 0.8697 - accuracy: 0.7934 - f_score: 0.8057 - val_loss: 1.3303 - val_precision: 1.0000 - val_recall: 0.2810 - val_auc: 0.8836 - val_accuracy: 0.3450 - val_f_score: 0.4262 - lr: 0.0200
# Epoch 6/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4254 - precision: 0.8148 - recall: 0.8348 - auc: 0.8843 - accuracy: 0.8082 - f_score: 0.8183 - val_loss: 0.5459 - val_precision: 0.9836 - val_recall: 0.7196 - val_auc: 0.8791 - val_accuracy: 0.7336 - val_f_score: 0.8243 - lr: 0.0020
# Epoch 7/45
# 1124/1124 [==============================] - 152s 135ms/step - loss: 0.4185 - precision: 0.8171 - recall: 0.8449 - auc: 0.8887 - accuracy: 0.8140 - f_score: 0.8251 - val_loss: 0.6267 - val_precision: 0.9886 - val_recall: 0.6547 - val_auc: 0.8796 - val_accuracy: 0.6785 - val_f_score: 0.7791 - lr: 0.0020
# Epoch 8/45
# 1124/1124 [==============================] - 151s 134ms/step - loss: 0.4169 - precision: 0.8193 - recall: 0.8458 - auc: 0.8896 - accuracy: 0.8159 - f_score: 0.8280 - val_loss: 0.6436 - val_precision: 0.9882 - val_recall: 0.6358 - val_auc: 0.8787 - val_accuracy: 0.6613 - val_f_score: 0.7672 - lr: 0.0020
# Epoch 9/45
# 1124/1124 [==============================] - 147s 130ms/step - loss: 0.4171 - precision: 0.8198 - recall: 0.8416 - auc: 0.8896 - accuracy: 0.8145 - f_score: 0.8256 - val_loss: 0.6244 - val_precision: 0.9875 - val_recall: 0.6484 - val_auc: 0.8772 - val_accuracy: 0.6722 - val_f_score: 0.7762 - lr: 0.0020
# Epoch 10/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4181 - precision: 0.8150 - recall: 0.8478 - auc: 0.8888 - accuracy: 0.8137 - f_score: 0.8259 - val_loss: 0.6624 - val_precision: 0.9880 - val_recall: 0.6200 - val_auc: 0.8767 - val_accuracy: 0.6470 - val_f_score: 0.7546 - lr: 2.0000e-04
# Epoch 11/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4196 - precision: 0.8141 - recall: 0.8427 - auc: 0.8875 - accuracy: 0.8110 - f_score: 0.8223 - val_loss: 0.6213 - val_precision: 0.9885 - val_recall: 0.6522 - val_auc: 0.8775 - val_accuracy: 0.6762 - val_f_score: 0.7775 - lr: 2.0000e-04
# Epoch 12/45
# 1124/1124 [==============================] - 143s 127ms/step - loss: 0.4156 - precision: 0.8187 - recall: 0.8448 - auc: 0.8896 - accuracy: 0.8150 - f_score: 0.8271 - val_loss: 0.6427 - val_precision: 0.9882 - val_recall: 0.6333 - val_auc: 0.8752 - val_accuracy: 0.6590 - val_f_score: 0.7646 - lr: 2.0000e-04
# Epoch 13/45
# 1124/1124 [==============================] - 147s 130ms/step - loss: 0.4185 - precision: 0.8189 - recall: 0.8422 - auc: 0.8887 - accuracy: 0.8141 - f_score: 0.8254 - val_loss: 0.6384 - val_precision: 0.9882 - val_recall: 0.6333 - val_auc: 0.8770 - val_accuracy: 0.6590 - val_f_score: 0.7639 - lr: 2.0000e-04
# Epoch 14/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4160 - precision: 0.8174 - recall: 0.8481 - auc: 0.8896 - accuracy: 0.8155 - f_score: 0.8276 - val_loss: 0.6481 - val_precision: 0.9881 - val_recall: 0.6289 - val_auc: 0.8773 - val_accuracy: 0.6550 - val_f_score: 0.7612 - lr: 2.0000e-05
# Epoch 15/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4121 - precision: 0.8174 - recall: 0.8471 - auc: 0.8919 - accuracy: 0.8151 - f_score: 0.8270 - val_loss: 0.6230 - val_precision: 0.9876 - val_recall: 0.6509 - val_auc: 0.8760 - val_accuracy: 0.6745 - val_f_score: 0.7777 - lr: 2.0000e-05
# Epoch 16/45
# 1124/1124 [==============================] - 142s 127ms/step - loss: 0.4132 - precision: 0.8179 - recall: 0.8448 - auc: 0.8913 - accuracy: 0.8145 - f_score: 0.8254 - val_loss: 0.6394 - val_precision: 0.9883 - val_recall: 0.6377 - val_auc: 0.8763 - val_accuracy: 0.6630 - val_f_score: 0.7692 - lr: 2.0000e-05
# Epoch 17/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4154 - precision: 0.8182 - recall: 0.8470 - auc: 0.8899 - accuracy: 0.8156 - f_score: 0.8264 - val_loss: 0.6477 - val_precision: 0.9881 - val_recall: 0.6289 - val_auc: 0.8771 - val_accuracy: 0.6550 - val_f_score: 0.7594 - lr: 2.0000e-05
# Epoch 18/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4156 - precision: 0.8179 - recall: 0.8476 - auc: 0.8899 - accuracy: 0.8157 - f_score: 0.8271 - val_loss: 0.6199 - val_precision: 0.9886 - val_recall: 0.6547 - val_auc: 0.8759 - val_accuracy: 0.6785 - val_f_score: 0.7791 - lr: 2.0000e-06
# Epoch 19/45
# 1124/1124 [==============================] - 148s 131ms/step - loss: 0.4143 - precision: 0.8166 - recall: 0.8470 - auc: 0.8904 - accuracy: 0.8145 - f_score: 0.8257 - val_loss: 0.6370 - val_precision: 0.9883 - val_recall: 0.6383 - val_auc: 0.8767 - val_accuracy: 0.6636 - val_f_score: 0.7707 - lr: 2.0000e-06
# Epoch 20/45
# 1124/1124 [==============================] - 147s 131ms/step - loss: 0.4136 - precision: 0.8198 - recall: 0.8503 - auc: 0.8911 - accuracy: 0.8181 - f_score: 0.8291 - val_loss: 0.6492 - val_precision: 0.9881 - val_recall: 0.6301 - val_auc: 0.8755 - val_accuracy: 0.6561 - val_f_score: 0.7606 - lr: 2.0000e-06
# Epoch 21/45
# 1124/1124 [==============================] - 151s 134ms/step - loss: 0.4152 - precision: 0.8171 - recall: 0.8449 - auc: 0.8899 - accuracy: 0.8140 - f_score: 0.8247 - val_loss: 0.6291 - val_precision: 0.9885 - val_recall: 0.6471 - val_auc: 0.8755 - val_accuracy: 0.6716 - val_f_score: 0.7748 - lr: 2.0000e-06
# Epoch 22/45
# 1124/1124 [==============================] - 147s 130ms/step - loss: 0.4159 - precision: 0.8147 - recall: 0.8466 - auc: 0.8892 - accuracy: 0.8130 - f_score: 0.8251 - val_loss: 0.6537 - val_precision: 0.9880 - val_recall: 0.6251 - val_auc: 0.8775 - val_accuracy: 0.6515 - val_f_score: 0.7593 - lr: 2.0000e-07
# Epoch 23/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4134 - precision: 0.8159 - recall: 0.8466 - auc: 0.8912 - accuracy: 0.8139 - f_score: 0.8257 - val_loss: 0.6087 - val_precision: 0.9878 - val_recall: 0.6641 - val_auc: 0.8746 - val_accuracy: 0.6866 - val_f_score: 0.7837 - lr: 2.0000e-07
# Epoch 24/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4188 - precision: 0.8188 - recall: 0.8448 - auc: 0.8883 - accuracy: 0.8151 - f_score: 0.8258 - val_loss: 0.6209 - val_precision: 0.9886 - val_recall: 0.6547 - val_auc: 0.8773 - val_accuracy: 0.6785 - val_f_score: 0.7813 - lr: 2.0000e-07
# Epoch 25/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4166 - precision: 0.8138 - recall: 0.8431 - auc: 0.8894 - accuracy: 0.8110 - f_score: 0.8235 - val_loss: 0.6626 - val_precision: 0.9880 - val_recall: 0.6238 - val_auc: 0.8759 - val_accuracy: 0.6504 - val_f_score: 0.7578 - lr: 2.0000e-07
# Epoch 26/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4169 - precision: 0.8172 - recall: 0.8441 - auc: 0.8893 - accuracy: 0.8137 - f_score: 0.8263 - val_loss: 0.6448 - val_precision: 0.9882 - val_recall: 0.6339 - val_auc: 0.8753 - val_accuracy: 0.6596 - val_f_score: 0.7643 - lr: 2.0000e-08
# Epoch 27/45
# 1124/1124 [==============================] - 143s 128ms/step - loss: 0.4158 - precision: 0.8199 - recall: 0.8476 - auc: 0.8898 - accuracy: 0.8170 - f_score: 0.8282 - val_loss: 0.6308 - val_precision: 0.9884 - val_recall: 0.6459 - val_auc: 0.8749 - val_accuracy: 0.6705 - val_f_score: 0.7756 - lr: 2.0000e-08
# Epoch 28/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4157 - precision: 0.8169 - recall: 0.8462 - auc: 0.8899 - accuracy: 0.8144 - f_score: 0.8262 - val_loss: 0.6381 - val_precision: 0.9883 - val_recall: 0.6389 - val_auc: 0.8759 - val_accuracy: 0.6642 - val_f_score: 0.7686 - lr: 2.0000e-08
# Epoch 29/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4227 - precision: 0.8142 - recall: 0.8408 - auc: 0.8859 - accuracy: 0.8103 - f_score: 0.8221 - val_loss: 0.6356 - val_precision: 0.9884 - val_recall: 0.6434 - val_auc: 0.8767 - val_accuracy: 0.6682 - val_f_score: 0.7730 - lr: 2.0000e-08
# Epoch 30/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4137 - precision: 0.8156 - recall: 0.8447 - auc: 0.8907 - accuracy: 0.8129 - f_score: 0.8249 - val_loss: 0.6274 - val_precision: 0.9885 - val_recall: 0.6471 - val_auc: 0.8774 - val_accuracy: 0.6716 - val_f_score: 0.7741 - lr: 2.0000e-09
# Epoch 31/45
# 1124/1124 [==============================] - 143s 127ms/step - loss: 0.4176 - precision: 0.8196 - recall: 0.8468 - auc: 0.8892 - accuracy: 0.8165 - f_score: 0.8285 - val_loss: 0.6391 - val_precision: 0.9882 - val_recall: 0.6333 - val_auc: 0.8761 - val_accuracy: 0.6590 - val_f_score: 0.7640 - lr: 2.0000e-09
# Epoch 32/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4173 - precision: 0.8157 - recall: 0.8428 - auc: 0.8887 - accuracy: 0.8121 - f_score: 0.8239 - val_loss: 0.6214 - val_precision: 0.9885 - val_recall: 0.6509 - val_auc: 0.8774 - val_accuracy: 0.6751 - val_f_score: 0.7787 - lr: 2.0000e-09
# Epoch 33/45
# 1124/1124 [==============================] - 143s 127ms/step - loss: 0.4145 - precision: 0.8167 - recall: 0.8401 - auc: 0.8900 - accuracy: 0.8117 - f_score: 0.8233 - val_loss: 0.6306 - val_precision: 0.9884 - val_recall: 0.6427 - val_auc: 0.8766 - val_accuracy: 0.6676 - val_f_score: 0.7734 - lr: 2.0000e-09
# Epoch 34/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4140 - precision: 0.8199 - recall: 0.8492 - auc: 0.8910 - accuracy: 0.8178 - f_score: 0.8299 - val_loss: 0.6250 - val_precision: 0.9885 - val_recall: 0.6522 - val_auc: 0.8758 - val_accuracy: 0.6762 - val_f_score: 0.7790 - lr: 2.0000e-10
# Epoch 35/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4122 - precision: 0.8160 - recall: 0.8459 - auc: 0.8917 - accuracy: 0.8136 - f_score: 0.8255 - val_loss: 0.6221 - val_precision: 0.9885 - val_recall: 0.6515 - val_auc: 0.8758 - val_accuracy: 0.6757 - val_f_score: 0.7802 - lr: 2.0000e-10
# Epoch 36/45
# 1124/1124 [==============================] - 146s 130ms/step - loss: 0.4128 - precision: 0.8229 - recall: 0.8428 - auc: 0.8916 - accuracy: 0.8170 - f_score: 0.8286 - val_loss: 0.6159 - val_precision: 0.9877 - val_recall: 0.6578 - val_auc: 0.8764 - val_accuracy: 0.6808 - val_f_score: 0.7810 - lr: 2.0000e-10
# Epoch 37/45
# 1124/1124 [==============================] - 145s 129ms/step - loss: 0.4191 - precision: 0.8186 - recall: 0.8395 - auc: 0.8882 - accuracy: 0.8127 - f_score: 0.8240 - val_loss: 0.6467 - val_precision: 0.9882 - val_recall: 0.6352 - val_auc: 0.8764 - val_accuracy: 0.6607 - val_f_score: 0.7651 - lr: 2.0000e-10
# Epoch 38/45
# 1124/1124 [==============================] - 152s 135ms/step - loss: 0.4133 - precision: 0.8186 - recall: 0.8478 - auc: 0.8913 - accuracy: 0.8162 - f_score: 0.8275 - val_loss: 0.6531 - val_precision: 0.9881 - val_recall: 0.6289 - val_auc: 0.8756 - val_accuracy: 0.6550 - val_f_score: 0.7603 - lr: 2.0000e-11
# Epoch 39/45
# 1124/1124 [==============================] - 148s 131ms/step - loss: 0.4145 - precision: 0.8169 - recall: 0.8467 - auc: 0.8905 - accuracy: 0.8146 - f_score: 0.8259 - val_loss: 0.6156 - val_precision: 0.9886 - val_recall: 0.6566 - val_auc: 0.8762 - val_accuracy: 0.6803 - val_f_score: 0.7817 - lr: 2.0000e-11
# Epoch 40/45
# 1124/1124 [==============================] - 146s 130ms/step - loss: 0.4174 - precision: 0.8179 - recall: 0.8439 - auc: 0.8886 - accuracy: 0.8141 - f_score: 0.8250 - val_loss: 0.6359 - val_precision: 0.9883 - val_recall: 0.6402 - val_auc: 0.8766 - val_accuracy: 0.6653 - val_f_score: 0.7703 - lr: 2.0000e-11
# Epoch 41/45
# 1124/1124 [==============================] - 147s 131ms/step - loss: 0.4133 - precision: 0.8205 - recall: 0.8480 - auc: 0.8911 - accuracy: 0.8176 - f_score: 0.8287 - val_loss: 0.6527 - val_precision: 0.9881 - val_recall: 0.6276 - val_auc: 0.8753 - val_accuracy: 0.6538 - val_f_score: 0.7613 - lr: 2.0000e-11
# Epoch 42/45
# 1124/1124 [==============================] - 146s 130ms/step - loss: 0.4140 - precision: 0.8164 - recall: 0.8428 - auc: 0.8909 - accuracy: 0.8126 - f_score: 0.8258 - val_loss: 0.6337 - val_precision: 0.9884 - val_recall: 0.6459 - val_auc: 0.8750 - val_accuracy: 0.6705 - val_f_score: 0.7739 - lr: 2.0000e-12
# Epoch 43/45
# 1124/1124 [==============================] - 143s 127ms/step - loss: 0.4181 - precision: 0.8179 - recall: 0.8433 - auc: 0.8884 - accuracy: 0.8139 - f_score: 0.8252 - val_loss: 0.6352 - val_precision: 0.9884 - val_recall: 0.6434 - val_auc: 0.8755 - val_accuracy: 0.6682 - val_f_score: 0.7699 - lr: 2.0000e-12
# Epoch 44/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4109 - precision: 0.8233 - recall: 0.8503 - auc: 0.8928 - accuracy: 0.8205 - f_score: 0.8317 - val_loss: 0.6237 - val_precision: 0.9885 - val_recall: 0.6509 - val_auc: 0.8758 - val_accuracy: 0.6751 - val_f_score: 0.7786 - lr: 2.0000e-12
# Epoch 45/45
# 1124/1124 [==============================] - 144s 128ms/step - loss: 0.4142 - precision: 0.8193 - recall: 0.8445 - auc: 0.8908 - accuracy: 0.8153 - f_score: 0.8262 - val_loss: 0.6586 - val_precision: 0.9880 - val_recall: 0.6251 - val_auc: 0.8748 - val_accuracy: 0.6515 - val_f_score: 0.7573 - lr: 2.0000e-12

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = dense.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 109/109 [==============================] - 16s 110ms/step
# AUC: 0.479106449580259
