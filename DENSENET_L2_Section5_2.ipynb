# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/DENSENET_L2_Section5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=32,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 32,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
from tensorflow.keras.regularizers import L1

dense = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.DenseNet201(include_top=False,
                   input_shape=(60,80,3),
                   pooling=None,classes=2)

for layer in pretrained_model.layers:
  layer.trainable=False

dense.add(pretrained_model)

dense.add(tf.keras.layers.Flatten())  # Use GlobalMaxPooling2D
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(512, activation='relu',kernel_regularizer=L1(0.01)))
dense.add(BatchNormalization())  # Add BatchNormalization layer
dense.add(tf.keras.layers.Dropout(0.2,activity_regularizer=L1(0.01))) #Add Dropout Layer
dense.add(tf.keras.layers.Dense(1, activation='sigmoid'))

dense.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 1, 2, 1920)        18321984
#
#  flatten (Flatten)           (None, 3840)              0
#
#  batch_normalization (BatchN  (None, 3840)             15360
#  ormalization)
#
#  dropout (Dropout)           (None, 3840)              0
#
#  dense (Dense)               (None, 512)               1966592
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 20,306,497
# Trainable params: 1,975,809
# Non-trainable params: 18,330,688
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.02)

dense.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history=dense.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=25,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 562/562 [==============================] - 5183s 9s/step - loss: 55.2078 - precision: 0.6634 - recall: 0.7677 - auc: 0.7184 - accuracy: 0.6640 - f_score: 0.7073 - val_loss: 51.0529 - val_precision: 0.9106 - val_recall: 0.9754 - val_auc: 0.3665 - val_accuracy: 0.8904 - val_f_score: 0.9410 - lr: 0.0200
# Epoch 2/45
# 562/562 [==============================] - 96s 171ms/step - loss: 49.1307 - precision: 0.6607 - recall: 0.7732 - auc: 0.7246 - accuracy: 0.6629 - f_score: 0.7088 - val_loss: 49.6398 - val_precision: 0.9121 - val_recall: 0.9288 - val_auc: 0.3862 - val_accuracy: 0.8536 - val_f_score: 0.9191 - lr: 0.0200
# Epoch 3/45
# 562/562 [==============================] - 94s 168ms/step - loss: 49.1866 - precision: 0.6590 - recall: 0.7802 - auc: 0.7147 - accuracy: 0.6630 - f_score: 0.7095 - val_loss: 47.7608 - val_precision: 0.9061 - val_recall: 0.5230 - val_auc: 0.4879 - val_accuracy: 0.5161 - val_f_score: 0.6583 - lr: 0.0200
# Epoch 4/45
# 562/562 [==============================] - 96s 170ms/step - loss: 49.2002 - precision: 0.6466 - recall: 0.7812 - auc: 0.7062 - accuracy: 0.6510 - f_score: 0.7026 - val_loss: 51.8521 - val_precision: 0.9078 - val_recall: 0.7070 - val_auc: 0.4103 - val_accuracy: 0.6676 - val_f_score: 0.7912 - lr: 0.0200
# Epoch 5/45
# 562/562 [==============================] - 96s 170ms/step - loss: 49.2135 - precision: 0.6523 - recall: 0.7809 - auc: 0.7107 - accuracy: 0.6566 - f_score: 0.7062 - val_loss: 49.1174 - val_precision: 0.9239 - val_recall: 0.8488 - val_auc: 0.5291 - val_accuracy: 0.7985 - val_f_score: 0.8818 - lr: 0.0200
# Epoch 6/45
# 562/562 [==============================] - 95s 170ms/step - loss: 6.1932 - precision: 0.6512 - recall: 0.8102 - auc: 0.7191 - accuracy: 0.6629 - f_score: 0.7180 - val_loss: 5.3621 - val_precision: 0.9261 - val_recall: 0.8847 - val_auc: 0.5127 - val_accuracy: 0.8307 - val_f_score: 0.9031 - lr: 0.0020
# Epoch 7/45
# 562/562 [==============================] - 93s 165ms/step - loss: 5.4135 - precision: 0.6442 - recall: 0.8147 - auc: 0.7176 - accuracy: 0.6568 - f_score: 0.7154 - val_loss: 5.4482 - val_precision: 0.9222 - val_recall: 0.8809 - val_auc: 0.4799 - val_accuracy: 0.8238 - val_f_score: 0.8987 - lr: 0.0020
# Epoch 8/45
# 562/562 [==============================] - 92s 164ms/step - loss: 5.4127 - precision: 0.6480 - recall: 0.8048 - auc: 0.7179 - accuracy: 0.6582 - f_score: 0.7144 - val_loss: 5.2710 - val_precision: 0.9197 - val_recall: 0.9313 - val_auc: 0.4500 - val_accuracy: 0.8634 - val_f_score: 0.9240 - lr: 0.0020
# Epoch 9/45
# 562/562 [==============================] - 95s 168ms/step - loss: 5.4061 - precision: 0.6524 - recall: 0.8089 - auc: 0.7248 - accuracy: 0.6638 - f_score: 0.7174 - val_loss: 5.3003 - val_precision: 0.9176 - val_recall: 0.9118 - val_auc: 0.4202 - val_accuracy: 0.8450 - val_f_score: 0.9130 - lr: 0.0020
# Epoch 10/45
# 562/562 [==============================] - 92s 164ms/step - loss: 1.1847 - precision: 0.6515 - recall: 0.7982 - auc: 0.7222 - accuracy: 0.6602 - f_score: 0.7137 - val_loss: 1.0411 - val_precision: 0.9180 - val_recall: 0.9238 - val_auc: 0.4155 - val_accuracy: 0.8553 - val_f_score: 0.9200 - lr: 2.0000e-04
# Epoch 11/45
# 562/562 [==============================] - 92s 163ms/step - loss: 1.1100 - precision: 0.6521 - recall: 0.8057 - auc: 0.7230 - accuracy: 0.6627 - f_score: 0.7176 - val_loss: 1.0312 - val_precision: 0.9185 - val_recall: 0.9307 - val_auc: 0.4033 - val_accuracy: 0.8617 - val_f_score: 0.9242 - lr: 2.0000e-04
# Epoch 12/45
# 562/562 [==============================] - 96s 171ms/step - loss: 1.1089 - precision: 0.6544 - recall: 0.8026 - auc: 0.7234 - accuracy: 0.6642 - f_score: 0.7166 - val_loss: 1.0187 - val_precision: 0.9193 - val_recall: 0.9332 - val_auc: 0.4131 - val_accuracy: 0.8645 - val_f_score: 0.9251 - lr: 2.0000e-04
# Epoch 13/45
# 562/562 [==============================] - 95s 169ms/step - loss: 1.1095 - precision: 0.6556 - recall: 0.8027 - auc: 0.7224 - accuracy: 0.6655 - f_score: 0.7182 - val_loss: 1.0234 - val_precision: 0.9187 - val_recall: 0.9263 - val_auc: 0.4213 - val_accuracy: 0.8582 - val_f_score: 0.9211 - lr: 2.0000e-04
# Epoch 14/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.6840 - precision: 0.6468 - recall: 0.7964 - auc: 0.7177 - accuracy: 0.6550 - f_score: 0.7089 - val_loss: 0.5995 - val_precision: 0.9188 - val_recall: 0.9200 - val_auc: 0.4258 - val_accuracy: 0.8530 - val_f_score: 0.9180 - lr: 2.0000e-05
# Epoch 15/45
# 562/562 [==============================] - 98s 174ms/step - loss: 0.6771 - precision: 0.6515 - recall: 0.8027 - auc: 0.7194 - accuracy: 0.6613 - f_score: 0.7152 - val_loss: 0.5976 - val_precision: 0.9187 - val_recall: 0.9263 - val_auc: 0.4203 - val_accuracy: 0.8582 - val_f_score: 0.9220 - lr: 2.0000e-05
# Epoch 16/45
# 562/562 [==============================] - 108s 192ms/step - loss: 0.6743 - precision: 0.6561 - recall: 0.8081 - auc: 0.7238 - accuracy: 0.6674 - f_score: 0.7202 - val_loss: 0.5996 - val_precision: 0.9188 - val_recall: 0.9193 - val_auc: 0.4256 - val_accuracy: 0.8525 - val_f_score: 0.9183 - lr: 2.0000e-05
# Epoch 17/45
# 562/562 [==============================] - 118s 209ms/step - loss: 0.6723 - precision: 0.6521 - recall: 0.8059 - auc: 0.7243 - accuracy: 0.6627 - f_score: 0.7168 - val_loss: 0.5969 - val_precision: 0.9188 - val_recall: 0.9269 - val_auc: 0.4165 - val_accuracy: 0.8588 - val_f_score: 0.9221 - lr: 2.0000e-05
# Epoch 18/45
# 562/562 [==============================] - 100s 177ms/step - loss: 0.6336 - precision: 0.6481 - recall: 0.8038 - auc: 0.7186 - accuracy: 0.6581 - f_score: 0.7136 - val_loss: 0.5505 - val_precision: 0.9192 - val_recall: 0.9313 - val_auc: 0.4150 - val_accuracy: 0.8628 - val_f_score: 0.9236 - lr: 2.0000e-06
# Epoch 19/45
# 562/562 [==============================] - 94s 167ms/step - loss: 0.6308 - precision: 0.6503 - recall: 0.8040 - auc: 0.7203 - accuracy: 0.6605 - f_score: 0.7157 - val_loss: 0.5505 - val_precision: 0.9192 - val_recall: 0.9319 - val_auc: 0.4126 - val_accuracy: 0.8634 - val_f_score: 0.9236 - lr: 2.0000e-06
# Epoch 20/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.6306 - precision: 0.6521 - recall: 0.8059 - auc: 0.7249 - accuracy: 0.6627 - f_score: 0.7174 - val_loss: 0.5458 - val_precision: 0.9195 - val_recall: 0.9357 - val_auc: 0.4152 - val_accuracy: 0.8668 - val_f_score: 0.9266 - lr: 2.0000e-06
# Epoch 21/45
# 562/562 [==============================] - 98s 174ms/step - loss: 0.6280 - precision: 0.6543 - recall: 0.8115 - auc: 0.7269 - accuracy: 0.6664 - f_score: 0.7204 - val_loss: 0.5496 - val_precision: 0.9193 - val_recall: 0.9332 - val_auc: 0.4162 - val_accuracy: 0.8645 - val_f_score: 0.9256 - lr: 2.0000e-06
# Epoch 22/45
# 562/562 [==============================] - 96s 170ms/step - loss: 0.6255 - precision: 0.6510 - recall: 0.8075 - auc: 0.7221 - accuracy: 0.6620 - f_score: 0.7164 - val_loss: 0.5465 - val_precision: 0.9193 - val_recall: 0.9332 - val_auc: 0.4125 - val_accuracy: 0.8645 - val_f_score: 0.9250 - lr: 2.0000e-07
# Epoch 23/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.6281 - precision: 0.6468 - recall: 0.7998 - auc: 0.7180 - accuracy: 0.6558 - f_score: 0.7119 - val_loss: 0.5465 - val_precision: 0.9192 - val_recall: 0.9313 - val_auc: 0.4140 - val_accuracy: 0.8628 - val_f_score: 0.9230 - lr: 2.0000e-07
# Epoch 24/45
# 562/562 [==============================] - 95s 168ms/step - loss: 0.6209 - precision: 0.6573 - recall: 0.8119 - auc: 0.7300 - accuracy: 0.6696 - f_score: 0.7227 - val_loss: 0.5494 - val_precision: 0.9187 - val_recall: 0.9256 - val_auc: 0.4177 - val_accuracy: 0.8576 - val_f_score: 0.9211 - lr: 2.0000e-07
# Epoch 25/45
# 562/562 [==============================] - 95s 169ms/step - loss: 0.6260 - precision: 0.6525 - recall: 0.8068 - auc: 0.7228 - accuracy: 0.6634 - f_score: 0.7176 - val_loss: 0.5474 - val_precision: 0.9189 - val_recall: 0.9275 - val_auc: 0.4157 - val_accuracy: 0.8594 - val_f_score: 0.9220 - lr: 2.0000e-07
# Epoch 26/45
# 562/562 [==============================] - 94s 166ms/step - loss: 0.6268 - precision: 0.6561 - recall: 0.8102 - auc: 0.7231 - accuracy: 0.6679 - f_score: 0.7215 - val_loss: 0.5454 - val_precision: 0.9191 - val_recall: 0.9307 - val_auc: 0.4176 - val_accuracy: 0.8622 - val_f_score: 0.9234 - lr: 2.0000e-08

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()
