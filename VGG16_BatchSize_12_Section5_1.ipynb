# %% [markdown]
# <a href="https://colab.research.google.com/github/ROPDIS/Models/blob/main/VGG16_BatchSize_12_Section5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Load the dependencies

# %%
import numpy as np
import torch
import cv2 as cv2
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os
from pathlib import Path
import glob
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.metrics import Precision, Recall, AUC

# %% [markdown]
# Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Step 3: Import Images

# %%
train_path = Path("/content/gdrive/MyDrive/Dis/Training Set Thumbnails")
test_path= Path("/content/gdrive/MyDrive/Dis/TestSetThumbnails")

test = Path('/content/gdrive/MyDrive/')

# %% [markdown]
# Training Data

# %%
train_paths = list(train_path.glob(r"**/*.jpg"))

# %% [markdown]
# Testing Set

# %%
test_paths = list(test_path.glob(r"**/*.jpg"))

# %% [markdown]
# Image Pre-processing

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size=(60,80),
                                        batch_size=12,
                                        class_mode='binary')
# Out:
# Found 17970 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(test_path, batch_size = 12,target_size=(60,80),class_mode='binary')
# Out:
# Found 1742 images belonging to 2 classes.

# %% [markdown]
# Calculating F-score

# %%
def f_score(y_true, y_pred):
    true_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.backend.sum(K.backend.round(K.backend.clip(y_true, 0, 1)))
    predicted_positives = K.backend.sum(K.backend.round(K.backend.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.backend.epsilon())
    recall = true_positives / (possible_positives + K.backend.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.backend.epsilon())
    return f1_val

# %%
# Custom Metric Functions
precision = Precision(name='precision')
recall = Recall(name='recall')
auc = AUC(name='auc')

# %% [markdown]
# CNN Model

# %%
VGG = tf.keras.models.Sequential()

pretrained_model= tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(60,80,3),
    pooling=None)

for layer in pretrained_model.layers:
    layer.trainable = False

VGG.add(pretrained_model)

VGG.add(tf.keras.layers.Flatten())
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(512, activation='relu'))
VGG.add(BatchNormalization())  # Add BatchNormalization layer
VGG.add(tf.keras.layers.Dropout(0.2)) #Add Dropout Layer
VGG.add(tf.keras.layers.Dense(1, activation='sigmoid'))

VGG.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 1, 2, 512)         14714688
#
#  flatten_2 (Flatten)         (None, 1024)              0
#
#  batch_normalization_4 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 15,246,145
# Trainable params: 528,385
# Non-trainable params: 14,717,760
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

optimizer_adam=Adam(learning_rate=0.002)

VGG.compile(optimizer=optimizer_adam, loss='binary_crossentropy', metrics=[precision, recall, auc, 'accuracy',f_score])

# %%
history = VGG.fit(
    training_set,
    validation_data=test_set,
    epochs=45,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=15,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_accuracy',
            factor=0.1,
            patience=4
        )
    ]
)
# Out:
# Epoch 1/45
# 1498/1498 [==============================] - 90s 59ms/step - loss: 0.5434 - precision: 0.7571 - recall: 0.7796 - auc: 0.8160 - accuracy: 0.7457 - f_score: 0.7591 - val_loss: 0.7271 - val_precision: 0.9625 - val_recall: 0.5822 - val_auc: 0.7491 - val_accuracy: 0.5987 - val_f_score: 0.7164 - lr: 0.0020
# Epoch 2/45
# 1498/1498 [==============================] - 93s 62ms/step - loss: 0.4962 - precision: 0.7746 - recall: 0.8002 - auc: 0.8409 - accuracy: 0.7662 - f_score: 0.7793 - val_loss: 0.5672 - val_precision: 0.9751 - val_recall: 0.6900 - val_auc: 0.8391 - val_accuracy: 0.7015 - val_f_score: 0.8007 - lr: 0.0020
# Epoch 3/45
# 1498/1498 [==============================] - 91s 61ms/step - loss: 0.4832 - precision: 0.7843 - recall: 0.8042 - auc: 0.8498 - accuracy: 0.7747 - f_score: 0.7856 - val_loss: 0.8017 - val_precision: 0.9841 - val_recall: 0.5476 - val_auc: 0.8095 - val_accuracy: 0.5798 - val_f_score: 0.6880 - lr: 0.0020
# Epoch 4/45
# 1498/1498 [==============================] - 90s 60ms/step - loss: 0.4770 - precision: 0.7874 - recall: 0.8063 - auc: 0.8523 - accuracy: 0.7777 - f_score: 0.7889 - val_loss: 1.0074 - val_precision: 0.9890 - val_recall: 0.4512 - val_auc: 0.8217 - val_accuracy: 0.4954 - val_f_score: 0.6107 - lr: 0.0020
# Epoch 5/45
# 1498/1498 [==============================] - 90s 60ms/step - loss: 0.4717 - precision: 0.7866 - recall: 0.8059 - auc: 0.8559 - accuracy: 0.7770 - f_score: 0.7884 - val_loss: 0.7675 - val_precision: 0.9757 - val_recall: 0.5312 - val_auc: 0.8108 - val_accuracy: 0.5608 - val_f_score: 0.6776 - lr: 0.0020
# Epoch 6/45
# 1498/1498 [==============================] - 88s 58ms/step - loss: 0.4696 - precision: 0.7945 - recall: 0.8132 - auc: 0.8574 - accuracy: 0.7854 - f_score: 0.7961 - val_loss: 0.7236 - val_precision: 0.9778 - val_recall: 0.5835 - val_auc: 0.8103 - val_accuracy: 0.6085 - val_f_score: 0.7188 - lr: 0.0020
# Epoch 7/45
# 1498/1498 [==============================] - 86s 57ms/step - loss: 0.4540 - precision: 0.8024 - recall: 0.8169 - auc: 0.8674 - accuracy: 0.7924 - f_score: 0.8030 - val_loss: 0.8360 - val_precision: 0.9812 - val_recall: 0.5255 - val_auc: 0.8114 - val_accuracy: 0.5586 - val_f_score: 0.6725 - lr: 2.0000e-04
# Epoch 8/45
# 1498/1498 [==============================] - 87s 58ms/step - loss: 0.4498 - precision: 0.7980 - recall: 0.8221 - auc: 0.8697 - accuracy: 0.7914 - f_score: 0.8021 - val_loss: 0.8386 - val_precision: 0.9839 - val_recall: 0.5406 - val_auc: 0.8194 - val_accuracy: 0.5735 - val_f_score: 0.6843 - lr: 2.0000e-04
# Epoch 9/45
# 1498/1498 [==============================] - 84s 56ms/step - loss: 0.4490 - precision: 0.8033 - recall: 0.8207 - auc: 0.8703 - accuracy: 0.7945 - f_score: 0.8045 - val_loss: 0.8844 - val_precision: 0.9855 - val_recall: 0.5135 - val_auc: 0.8190 - val_accuracy: 0.5499 - val_f_score: 0.6610 - lr: 2.0000e-04
# Epoch 10/45
# 1498/1498 [==============================] - 84s 56ms/step - loss: 0.4412 - precision: 0.8088 - recall: 0.8233 - auc: 0.8753 - accuracy: 0.7993 - f_score: 0.8087 - val_loss: 0.8179 - val_precision: 0.9852 - val_recall: 0.5457 - val_auc: 0.8259 - val_accuracy: 0.5786 - val_f_score: 0.6905 - lr: 2.0000e-04
# Epoch 11/45
# 1498/1498 [==============================] - 83s 56ms/step - loss: 0.4462 - precision: 0.8035 - recall: 0.8255 - auc: 0.8723 - accuracy: 0.7966 - f_score: 0.8066 - val_loss: 0.8398 - val_precision: 0.9847 - val_recall: 0.5280 - val_auc: 0.8251 - val_accuracy: 0.5626 - val_f_score: 0.6667 - lr: 2.0000e-05
# Epoch 12/45
# 1498/1498 [==============================] - 85s 57ms/step - loss: 0.4434 - precision: 0.8051 - recall: 0.8244 - auc: 0.8737 - accuracy: 0.7973 - f_score: 0.8068 - val_loss: 0.8309 - val_precision: 0.9849 - val_recall: 0.5337 - val_auc: 0.8287 - val_accuracy: 0.5677 - val_f_score: 0.6825 - lr: 2.0000e-05
# Epoch 13/45
# 1498/1498 [==============================] - 83s 55ms/step - loss: 0.4490 - precision: 0.8038 - recall: 0.8191 - auc: 0.8706 - accuracy: 0.7942 - f_score: 0.8037 - val_loss: 0.7943 - val_precision: 0.9865 - val_recall: 0.5507 - val_auc: 0.8330 - val_accuracy: 0.5838 - val_f_score: 0.6867 - lr: 2.0000e-05
# Epoch 14/45
# 1498/1498 [==============================] - 83s 56ms/step - loss: 0.4501 - precision: 0.7994 - recall: 0.8154 - auc: 0.8698 - accuracy: 0.7896 - f_score: 0.8007 - val_loss: 0.8475 - val_precision: 0.9858 - val_recall: 0.5236 - val_auc: 0.8285 - val_accuracy: 0.5591 - val_f_score: 0.6771 - lr: 2.0000e-05
# Epoch 15/45
# 1498/1498 [==============================] - 83s 55ms/step - loss: 0.4387 - precision: 0.8072 - recall: 0.8278 - auc: 0.8767 - accuracy: 0.8001 - f_score: 0.8111 - val_loss: 0.8092 - val_precision: 0.9860 - val_recall: 0.5337 - val_auc: 0.8287 - val_accuracy: 0.5683 - val_f_score: 0.6784 - lr: 2.0000e-06
# Epoch 16/45
# 1498/1498 [==============================] - 83s 55ms/step - loss: 0.4489 - precision: 0.8018 - recall: 0.8237 - auc: 0.8705 - accuracy: 0.7947 - f_score: 0.8047 - val_loss: 0.8111 - val_precision: 0.9860 - val_recall: 0.5325 - val_auc: 0.8272 - val_accuracy: 0.5672 - val_f_score: 0.6806 - lr: 2.0000e-06
# Epoch 17/45
# 1498/1498 [==============================] - 82s 55ms/step - loss: 0.4437 - precision: 0.8058 - recall: 0.8201 - auc: 0.8737 - accuracy: 0.7960 - f_score: 0.8059 - val_loss: 0.7821 - val_precision: 0.9854 - val_recall: 0.5545 - val_auc: 0.8284 - val_accuracy: 0.5867 - val_f_score: 0.7004 - lr: 2.0000e-06

# %%
import matplotlib.pyplot as plt
# Plot the training and validation accuracy and loss
plt.figure(figsize=(15, 7))

plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.subplot(2, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Training AUC')
plt.plot(history.history['val_auc'], label='Validation AUC')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('AUC')

plt.subplot(2, 2, 4)
plt.plot(history.history['f_score'], label='Training Fscore')
plt.plot(history.history['val_f_score'], label='Validation Fscore')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('F Score')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score


# Make predictions on the test data
y_pred_prob = VGG.predict(test_set)

# Convert predicted probabilities to binary predictions (0 or 1)
y_pred = np.round(y_pred_prob).flatten()

# Get true target labels
y_true = test_set.classes

# Calculate the AUC
auc = roc_auc_score(y_true, y_pred_prob)

# Plot the ROC curve
fpr, tpr, _ = roc_curve(y_true, y_pred_prob)
plt.plot(fpr, tpr, label='ROC Curve (AUC = {:.2f})'.format(auc))
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()

# Print the AUC
print("AUC:", auc)
# Out:
# 146/146 [==============================] - 6s 41ms/step
# AUC: 0.5140476045287314
